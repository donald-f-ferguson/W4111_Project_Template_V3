# %% [markdown]
# <span style="font-size: 36px;">W4111_Spring_2025_002 - Introduction to Databases:<br>All Tracks Data Engineering Phase 1<br>Professor Ferguson's Example</br></span>

# %% [markdown]
# # Overview

# %% [markdown]
# ## Application Scenario

# %% [markdown]
# The following diagram depicts some major elements of the applications.
# - Both tracks implement a simple [data engineering](https://en.wikipedia.org/wiki/Data_engineering) project, specifically an [extract-transform-load](https://en.wikipedia.org/wiki/Extract,_transform,_load) application in a Jupyter notebook.
#   - The input datatsets are information from [IMDB](https://developer.imdb.com/non-commercial-datasets/) and information about [Game of Thrones](https://github.com/jeffreylancaster/game-of-thrones).
#   - The data engineering tasks process and load information into three databases:
#       - A local installation of MySQL
#       - A cloud document database on [MongoDB Atlas](https://www.mongodb.com/atlas)
#       - A graph database on [Neo4j Aura](https://neo4j.com/product/auradb/)
#   - The programming track implements a simple full-stack web application that supports searching and displaying information, and also adds creating and update additional data.
# - The non-programming track implements:
#   - Additional data engineering tasks to build a [data warehouse](https://en.wikipedia.org/wiki/Data_warehouse) that provides the data in a format suitable for decision support/data science.
#   - A very simply decision support/data insight application in a Jupyter notebook. The application queries the various databases to produce "views" that can be used for visualization.

# %% [markdown]
# | <img src="overall-system.jpg" width="1000px;"> |
# | :---: |
# | __Overall Application Concept__ |

# %% [markdown]
# ## Data Engineering

# %% [markdown]
# The following diagram is an overview of data engineering concepts, and entity-relationship modeling in general.
#
# | <img src="top_down_bottom_up.jpg" width="900px;"> |
# | :---: |
# | __Data Modeling__ |
#
# The data engineering tasks for the project are primarily _bottom-up data analysis and engineering._ There are two datasets that are the input to the data engineering:
# 1. IMDB data in comma separated value file.
# 2. Games-of-Thrones data in [JSON](https://en.wikipedia.org/wiki/JSON) files.
#
# This Jupyter notebook provides some examples for the first phase of data engineering:
# 1. The initial data loading.
# 1. Define the "to be" data model.
# 2. How to map from the "as is" data to the "to be" data.
#
# The providing the information in the project example helps students some understand the project tasks.

# %% [markdown]
# | <img src="data-janitor.jpg" width="900px;"> |
# | :---: |
# | __Data Engineering__ |

# %% [markdown]
# # Initialization

# %% [markdown]
# ## General Python Packages

# %%
import copy

# %%
import json

# %%
import pandas

# %%
import numpy

# %% [markdown]
# ## MySQL

# %% [markdown]
# ### Import Packages

# %%
# You should have installed the packages for previous homework assignments
# If not, you can %pip install the packages.
#
import pymysql
import sqlalchemy

# %% [markdown]
# ### ipython-sql

# %%
# This fixes a version incpatibility problem between ipython-sql and other packages.
# You may not need to do this. If it causes problems, you can restart the kernel, reimport the packages above
# and try skipping this cell.
#
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %%
# You have installed and configured ipython-sql for previous assignments.
# https://pypi.org/project/ipython-sql/
#
# %load_ext sql

# %%
# Make sure that you set these values to the correct values for your installation and 
# configuration of MySQL
#
db_user = "root"
db_password = "dbuserdbuser"

# %%
# Create the URL for connecting to the database.
# Do not worry about the local_infile=1, I did that for wizard reasons that you should not have to use.
#
db_url = f"mysql+pymysql://{db_user}:{db_password}@localhost?local_infile=1"

# %%
# Initialize ipython-sql
#
# %sql $db_url

# %%
# Your answer MAY be different based on the databases and tables that you have created on your local MySQL instance.
#
# %sql use db_book;
# %sql show tables;
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 0 rows affected.
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 15 rows affected.
# [('advisor',),
#  ('classroom',),
#  ('course',),
#  ('department',),
#  ('hw3_student',),
#  ('hw3_student_simple_1',),
#  ('hw3_student_simple_2',),
#  ('instructor',),
#  ('instructor_public',),
#  ('prereq',),
#  ('section',),
#  ('student',),
#  ('takes',),
#  ('teaches',),
#  ('time_slot',)]

# %% [markdown]
# ### PyMySQL

# %%
# We talked about the concept of a connection to databases in general, and also about connection libraries.
# pymysql is a common python connection library for MySQL.
#
default_mysql_conn = pymysql.connect(
    user=db_user,
    password=db_password,
    host="localhost",
    port=3306,
    cursorclass=pymysql.cursors.DictCursor,
    autocommit=True
)

# %%
# This cell shows how to programatically query an SQL database from python. The programming track will have to use
# code like this in their project. The non-programming track may have to use code like this in some complex scenarios.
#
cur = default_mysql_conn.cursor()

result = cur.execute("select * from db_book.student where dept_name='Comp. Sci.';");
result = cur.fetchall()
result_df = pandas.DataFrame(result)
result_df
# Out:
#       ID      name   dept_name tot_cred
# 0  00128     Zhang  Comp. Sci.      102
# 1  12345   Shankar  Comp. Sci.       32
# 2  54321  Williams  Comp. Sci.       54
# 3  76543     Brown  Comp. Sci.       58

# %% [markdown]
# ### SQLAlchemy

# %%
# SQLAlchemy is a common foundational library for connecting to SQL databases. Pandas integrates with SQLAlchemy.
# SQLAlchemy also support object-relational-mapping, but we do not use those features.
#
from sqlalchemy import create_engine
default_engine = create_engine(db_url)

# %%
result_df = pandas.read_sql(
    "select * from db_book.student where dept_name='Comp. Sci.'", con=default_engine
)
result_df
# Out:
#       ID      name   dept_name  tot_cred
# 0  00128     Zhang  Comp. Sci.     102.0
# 1  12345   Shankar  Comp. Sci.      32.0
# 2  54321  Williams  Comp. Sci.      54.0
# 3  76543     Brown  Comp. Sci.      58.0

# %% [markdown]
# ## MongoDB

# %% [markdown]
# ### Installation

# %% [markdown]
# Students have two choices for MongoDB:
# 1. Install a local instance of [MongoDB](https://www.mongodb.com/docs/manual/installation/) and [Compass.](https://www.mongodb.com/docs/compass/current/install/)
# 2. Use a [SaaS/cloud](https://en.wikipedia.org/wiki/Software_as_a_service) version of MongoDB and Compass. This gives students some experience with [Database-as-a-Service](https://en.wikipedia.org/wiki/Data_as_a_service), which may sound cool on job interviews.
#
#
# Setup and configuration may be a little tricky in both cases. This is a 4xxx course at an elite university. Regardless of your major, any job with data is going to expect you to be able to set up, configure and connect to a database. There is a ton of online instructions, tutorials, videos, etc. on how to accomplish these tasks.
#
#
# If you are using MongoDB Atlas you will need to create a cluster and get the connection URL. You will also need to have a user ID and password. Again, you should be able to figure this out. READ THE INSTRUCTIONS AND TUTORIALS.

# %% [markdown]
# | <img src="manual.jpg"> |
# | :---: |
# | __Read the Manual and Instructions__|

# %% [markdown]
# ### Connect and Test

# %% [markdown]
# I use MongoDB Atlas. I Created the account using my Columbia login UNI. I also wrote down the password.

# %%
# You may have to do a pip install.
#
# %pip install pymongo

# %%
import pymongo

# %%
# Put your user ID and password here.
#
mongodb_user_id = "dff9"
mongodb_password = "fquYGkveLj3XXZCt"

# %%
# Follow the instruction for getting a python connection URL and code.
# Replace <db_password> with your MongoDB password
#
mongodb_url = "mongodb+srv://dff9:<db_password>@cluster0.t8qdk.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
# This is my connection URL.
#
mongodb_url = "mongodb+srv://dff9:fquYGkveLj3XXZCt@cluster0.t8qdk.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
# You can follow the tutorial.
#
from pymongo import MongoClient
import certifi

client = pymongo.MongoClient(mongodb_url, tlsCAFile=certifi.where())

# client = MongoClient(mongodb_url)

try:
    # start example code here

    # end example code here

    client.admin.command("ping")
    print("Connected successfully")

    # other application code

    # client.close()

except Exception as e:
    raise Exception(
        "The following error occurred: ", e)
# Out:
# Connected successfully

# %%
# Create a test database and collection.
#
database = client["test_database"]
collection = database["test_collection"]

# %%
# Add some data.
#
document_list = [
   { "name" : "Mongo's Burgers" },
   { "name" : "Mongo's Pizza" }
]

insert_count = collection.insert_many(document_list)

# %%
# Get the IDs of the inserted objects.
insert_count.inserted_ids
# Out:
# [ObjectId('67f0ebdbeb5a9851a3008dcd'), ObjectId('67f0ebdbeb5a9851a3008dce')]

# %%
# Find matching objects.
# 
result = collection.find(
    filter={"name": "Mongo's Pizza"},
    projection={"_id": 0}
)

# %%
list(result)
# Out:
# [{'name': "Mongo's Pizza"}]

# %% [markdown]
# You are fine for now.

# %% [markdown]
# ## Neo4j

# %%
# You may have to do a pip install
#
# %pip install neo4j

# %% [markdown]
# You have two choices for getting access to Neo4j.
# - [Local installation](https://neo4j.com/download/) of Neo4j Desktop.
# - The SaaS version [Neo4j Aura](https://neo4j.com/download)
#
# My examples use Neo4j Aura. Once again, READ THE INSTRUCTIONS to install, configure, create a collection and run the Movies Graph examples.

# %% [markdown]
# | <img src="instructions.jpg" width="500px"> |
# | :---: |
# | __Read the Manual and Instructions__|

# %%
# Wait 60 seconds before connecting using these details, or login to https://console.neo4j.io to validate the Aura Instance is available
# 
# I used download to get my connection information. I had to add the " for the strings
#
NEO4J_URI="neo4j+s://da38d60b.databases.neo4j.io"
NEO4J_USERNAME="neo4j"
NEO4J_PASSWORD="ISBZxGQpxtJJqlSjr6GNKeFv0UYZgdKB1k9dl3aRKVw"
AURA_INSTANCEID="da38d60b"
AURA_INSTANCENAME="Instance01"

# %%
from neo4j import GraphDatabase

# URI examples: "neo4j://localhost", "neo4j+s://xxx.databases.neo4j.io"
#
# I changed +s to +ssc to make it work. ssc means self signed certificate. You would NEVER do this in practice.
# This is Wizard Sh*t and just for this class.
#
NEO4J_URI = "neo4j+ssc://da38d60b.databases.neo4j.io"
AUTH = (NEO4J_USERNAME, NEO4J_PASSWORD)

with GraphDatabase.driver(NEO4J_URI, auth=AUTH) as driver:
    result = driver.verify_connectivity()
    print("Since this did not explode, you are cool.")
# Out:
# Since this did not explode, you are cool.

# %%
# These cells assume that you followed the tutorial for the Movie Database.
# I showed how to do this in lecture 10, which very few of you attended or watched.
#
from neo4j import GraphDatabase


class Neo4jAuraDB:
    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))
        print("Created driver.")

    def close(self):
        self.driver.close()

    def find_person_by_name(self, name):
        query = """
        MATCH (p:Person {name: $name})
        RETURN p
        """
        with self.driver.session() as session:
            result = session.run(query, name=name)
            return [record["p"] for record in result]

# Example usage
if __name__ == "__main__":
    db = Neo4jAuraDB(NEO4J_URI, NEO4J_USERNAME, NEO4J_PASSWORD)
    try:
        people = db.find_person_by_name("Tom Hanks")
        if people:
            print("Found:")
            for person in people:
                print(dict(person))
        else:
            print("Tom Hanks not found.")
    finally:
        db.close()
# Out:
# Created driver.
# Found:
# {'born': 1956, 'name': 'Tom Hanks'}

# %% [markdown]
# You are golden if you got to here.

# %% [markdown]
# # Loading the Data

# %% [markdown]
# ## Load the GoT Title Basics and name_basics into MySQL

# %% [markdown]
# I am going to load basic ```title_basics``` information into a new database.

# %%
# %sql drop schema if exists s25_project
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 7 rows affected.
# []

# %%
# %sql create schema s25_project
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 1 rows affected.
# []

# %% [markdown]
# I am going to save the GoT ```title_basics.```

# %%
# %pwd
# Out:
# '/Users/donald.ferguson/Dropbox/000/00-Current-Repos/W4111_Project_Template_V3/common_data_engineering'

# %%
# This code assume you are running the notebook in the project cloned from GitHub and are in the
# correct directory.
#
default_engine = create_engine(db_url)
df = pandas.read_csv("../data/IMDB/got_title_basics.csv")
df.to_sql("got_title_basics", schema="s25_project", con=default_engine, index=False, if_exists="replace")
# Out:
# 73

# %%
# %sql use s25_project
# %sql select * from got_title_basics
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 0 rows affected.
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 73 rows affected.
# [(0, 'tt1480055', 'tvEpisode', 'Winter Is Coming', 'Winter Is Coming', 0, 2011, '\\N', 62, 'Action,Adventure,Drama'),
#  (1, 'tt1668746', 'tvEpisode', 'The Kingsroad', 'The Kingsroad', 0, 2011, '\\N', 56, 'Action,Adventure,Drama'),
#  (2, 'tt1829962', 'tvEpisode', 'Lord Snow', 'Lord Snow', 0, 2011, '\\N', 58, 'Action,Adventure,Drama'),
#  (3, 'tt1829963', 'tvEpisode', 'Cripples, Bastards, and Broken Things', 'Cripples, Bastards, and Broken Things', 0, 2011, '\\N', 56, 'Action,Adventure,Drama'),
#  (4, 'tt1829964', 'tvEpisode', 'The Wolf and the Lion', 'The Wolf and the Lion', 0, 2011, '\\N', 55, 'Action,Adventure,Drama'),
#  (5, 'tt1837862', 'tvEpisode', 'A Golden Crown', 'A Golden Crown', 0, 2011, '\\N', 53, 'Action,Adventure,Drama'),
#  (6, 'tt1837863', 'tvEpisode', 'You Win or You Die', 'You Win or You Die', 0, 2011, '\\N', 58, 'Action,Adventure,Drama'),
#  (7, 'tt1837864', 'tvEpisode', 'The Pointy End', 'The Pointy End', 0, 2011, '\\N', 59, 'Action,Adventure,Drama'),
#  (8, 'tt1851397', 'tvEpisode', 'Fire and Blood', 'Fire and Blood', 0, 2011, '\\N', 53, 'Action,Adventure,Drama'),
#  (9, 'tt1851398', 'tvEpisode', 'Baelor', 'Baelor', 0, 2011, '\\N', 57, 'Action,Adventure,Drama'),
#  (10, 'tt1971833', 'tvEpisode', 'The North Remembers', 'The North Remembers', 0, 2012, '\\N', 53, 'Action,Adventure,Drama'),
#  (11, 'tt2069318', 'tvEpisode', 'The Night Lands', 'The Night Lands', 0, 2012, '\\N', 54, 'Action,Adventure,Drama'),
#  (12, 'tt2069319', 'tvEpisode', 'Garden of Bones', 'Garden of Bones', 0, 2012, '\\N', 51, 'Action,Adventure,Drama'),
#  (13, 'tt2070135', 'tvEpisode', 'What Is Dead May Never Die', 'What Is Dead May Never Die', 0, 2012, '\\N', 53, 'Action,Adventure,Drama'),
#  (14, 'tt2074658', 'tvEpisode', 'The Ghost of Harrenhal', 'The Ghost of Harrenhal', 0, 2012, '\\N', 55, 'Action,Adventure,Drama'),
#  (15, 'tt2084342', 'tvEpisode', 'Blackwater', 'Blackwater', 0, 2012, '\\N', 55, 'Action,Adventure,Drama'),
#  (16, 'tt2085238', 'tvEpisode', 'The Old Gods and the New', 'The Old Gods and the New', 0, 2012, '\\N', 54, 'Action,Adventure,Drama'),
#  (17, 'tt2085239', 'tvEpisode', 'A Man Without Honor', 'A Man Without Honor', 0, 2012, '\\N', 56, 'Action,Adventure,Drama'),
#  (18, 'tt2085240', 'tvEpisode', 'The Prince of Winterfell', 'The Prince of Winterfell', 0, 2012, '\\N', 54, 'Action,Adventure,Drama'),
#  (19, 'tt2112510', 'tvEpisode', 'Valar Morghulis', 'Valar Morghulis', 0, 2012, '\\N', 64, 'Action,Adventure,Drama'),
#  (20, 'tt2178772', 'tvEpisode', 'Dark Wings, Dark Words', 'Dark Wings, Dark Words', 0, 2013, '\\N', 56, 'Action,Adventure,Drama'),
#  (21, 'tt2178782', 'tvEpisode', 'Valar Dohaeris', 'Valar Dohaeris', 0, 2013, '\\N', 55, 'Action,Adventure,Drama'),
#  (22, 'tt2178784', 'tvEpisode', 'The Rains of Castamere', 'The Rains of Castamere', 0, 2013, '\\N', 51, 'Action,Adventure,Drama'),
#  (23, 'tt2178788', 'tvEpisode', 'Kissed by Fire', 'Kissed by Fire', 0, 2013, '\\N', 57, 'Action,Adventure,Drama'),
#  (24, 'tt2178796', 'tvEpisode', 'Mhysa', 'Mhysa', 0, 2013, '\\N', 63, 'Action,Adventure,Drama'),
#  (25, 'tt2178798', 'tvEpisode', 'And Now His Watch Is Ended', 'And Now His Watch Is Ended', 0, 2013, '\\N', 53, 'Action,Adventure,Drama'),
#  (26, 'tt2178802', 'tvEpisode', 'Walk of Punishment', 'Walk of Punishment', 0, 2013, '\\N', 56, 'Action,Adventure,Drama'),
#  (27, 'tt2178806', 'tvEpisode', 'Second Sons', 'Second Sons', 0, 2013, '\\N', 56, 'Action,Adventure,Drama'),
#  (28, 'tt2178812', 'tvEpisode', 'The Climb', 'The Climb', 0, 2013, '\\N', 53, 'Action,Adventure,Drama'),
#  (29, 'tt2178814', 'tvEpisode', 'The Bear and the Maiden Fair', 'The Bear and the Maiden Fair', 0, 2013, '\\N', 58, 'Action,Adventure,Drama'),
#  (30, 'tt2816136', 'tvEpisode', 'Two Swords', 'Two Swords', 0, 2014, '\\N', 58, 'Action,Adventure,Drama'),
#  (31, 'tt2832378', 'tvEpisode', 'The Lion and the Rose', 'The Lion and the Rose', 0, 2014, '\\N', 52, 'Action,Adventure,Drama'),
#  (32, 'tt2972426', 'tvEpisode', 'Breaker of Chains', 'Breaker of Chains', 0, 2014, '\\N', 57, 'Action,Adventure,Drama'),
#  (33, 'tt2972428', 'tvEpisode', 'Oathkeeper', 'Oathkeeper', 0, 2014, '\\N', 55, 'Action,Adventure,Drama'),
#  (34, 'tt3060782', 'tvEpisode', 'The Mountain and the Viper', 'The Mountain and the Viper', 0, 2014, '\\N', 52, 'Action,Adventure,Drama'),
#  (35, 'tt3060856', 'tvEpisode', 'First of His Name', 'First of His Name', 0, 2014, '\\N', 53, 'Action,Adventure,Drama'),
#  (36, 'tt3060858', 'tvEpisode', 'The Watchers on the Wall', 'The Watchers on the Wall', 0, 2014, '\\N', 51, 'Action,Adventure,Drama'),
#  (37, 'tt3060860', 'tvEpisode', 'The Children', 'The Children', 0, 2014, '\\N', 65, 'Action,Adventure,Drama'),
#  (38, 'tt3060876', 'tvEpisode', 'Mockingbird', 'Mockingbird', 0, 2014, '\\N', 51, 'Action,Adventure,Drama'),
#  (39, 'tt3060910', 'tvEpisode', 'The Laws of Gods and Men', 'The Laws of Gods and Men', 0, 2014, '\\N', 51, 'Action,Adventure,Drama'),
#  (40, 'tt3658012', 'tvEpisode', 'The Wars to Come', 'The Wars to Come', 0, 2015, '\\N', 53, 'Action,Adventure,Drama'),
#  (41, 'tt3658014', 'tvEpisode', 'The Red Woman', 'The Red Woman', 0, 2016, '\\N', 50, 'Action,Adventure,Drama'),
#  (42, 'tt3846626', 'tvEpisode', 'The House of Black and White', 'The House of Black and White', 0, 2015, '\\N', 56, 'Action,Adventure,Drama'),
#  (43, 'tt3866826', 'tvEpisode', 'The Dance of Dragons', 'The Dance of Dragons', 0, 2015, '\\N', 52, 'Action,Adventure,Drama'),
#  (44, 'tt3866836', 'tvEpisode', 'High Sparrow', 'High Sparrow', 0, 2015, '\\N', 60, 'Action,Adventure,Drama'),
#  (45, 'tt3866838', 'tvEpisode', 'Sons of the Harpy', 'Sons of the Harpy', 0, 2015, '\\N', 51, 'Action,Adventure,Drama'),
#  (46, 'tt3866840', 'tvEpisode', 'Kill the Boy', 'Kill the Boy', 0, 2015, '\\N', 57, 'Action,Adventure,Drama'),
#  (47, 'tt3866842', 'tvEpisode', 'Unbowed, Unbent, Unbroken', 'Unbowed, Unbent, Unbroken', 0, 2015, '\\N', 54, 'Action,Adventure,Drama'),
#  (48, 'tt3866846', 'tvEpisode', 'The Gift', 'The Gift', 0, 2015, '\\N', 59, 'Action,Adventure,Drama'),
#  (49, 'tt3866850', 'tvEpisode', 'Hardhome', 'Hardhome', 0, 2015, '\\N', 61, 'Action,Adventure,Drama'),
#  (50, 'tt3866862', 'tvEpisode', "Mother's Mercy", "Mother's Mercy", 0, 2015, '\\N', 60, 'Action,Adventure,Drama'),
#  (51, 'tt4077554', 'tvEpisode', 'Home', 'Home', 0, 2016, '\\N', 54, 'Action,Adventure,Drama'),
#  (52, 'tt4131606', 'tvEpisode', 'Oathbreaker', 'Oathbreaker', 0, 2016, '\\N', 52, 'Action,Adventure,Drama'),
#  (53, 'tt4283016', 'tvEpisode', 'Book of the Stranger', 'Book of the Stranger', 0, 2016, '\\N', 59, 'Action,Adventure,Drama'),
#  (54, 'tt4283028', 'tvEpisode', 'The Door', 'The Door', 0, 2016, '\\N', 57, 'Action,Adventure,Drama'),
#  (55, 'tt4283054', 'tvEpisode', 'Blood of My Blood', 'Blood of My Blood', 0, 2016, '\\N', 52, 'Action,Adventure,Drama'),
#  (56, 'tt4283060', 'tvEpisode', 'The Broken Man', 'The Broken Man', 0, 2016, '\\N', 51, 'Action,Adventure,Drama'),
#  (57, 'tt4283074', 'tvEpisode', 'No One', 'No One', 0, 2016, '\\N', 59, 'Action,Adventure,Drama'),
#  (58, 'tt4283088', 'tvEpisode', 'Battle of the Bastards', 'Battle of the Bastards', 0, 2016, '\\N', 60, 'Action,Adventure,Drama'),
#  (59, 'tt4283094', 'tvEpisode', 'The Winds of Winter', 'The Winds of Winter', 0, 2016, '\\N', 68, 'Action,Adventure,Drama'),
#  (60, 'tt5654088', 'tvEpisode', 'Dragonstone', 'Dragonstone', 0, 2017, '\\N', 59, 'Action,Adventure,Drama'),
#  (61, 'tt5655178', 'tvEpisode', 'Stormborn', 'Stormborn', 0, 2017, '\\N', 59, 'Action,Adventure,Drama'),
#  (62, 'tt5775840', 'tvEpisode', "The Queen's Justice", "The Queen's Justice", 0, 2017, '\\N', 63, 'Action,Adventure,Drama'),
#  (63, 'tt5775846', 'tvEpisode', 'The Spoils of War', 'The Spoils of War', 0, 2017, '\\N', 50, 'Action,Adventure,Drama'),
#  (64, 'tt5775854', 'tvEpisode', 'Eastwatch', 'Eastwatch', 0, 2017, '\\N', 59, 'Action,Adventure,Drama'),
#  (65, 'tt5775864', 'tvEpisode', 'Beyond the Wall', 'Beyond the Wall', 0, 2017, '\\N', 70, 'Action,Adventure,Drama'),
#  (66, 'tt5775874', 'tvEpisode', 'The Dragon and the Wolf', 'The Dragon and the Wolf', 0, 2017, '\\N', 80, 'Action,Adventure,Drama'),
#  (67, 'tt5924366', 'tvEpisode', 'Winterfell', 'Winterfell', 0, 2019, '\\N', 54, 'Action,Adventure,Drama'),
#  (68, 'tt6027908', 'tvEpisode', 'A Knight of the Seven Kingdoms', 'A Knight of the Seven Kingdoms', 0, 2019, '\\N', 58, 'Action,Adventure,Drama'),
#  (69, 'tt6027912', 'tvEpisode', 'The Long Night', 'The Long Night', 0, 2019, '\\N', 82, 'Action,Adventure,Drama'),
#  (70, 'tt6027914', 'tvEpisode', 'The Last of the Starks', 'The Last of the Starks', 0, 2019, '\\N', 78, 'Action,Adventure,Drama'),
#  (71, 'tt6027916', 'tvEpisode', 'The Bells', 'The Bells', 0, 2019, '\\N', 78, 'Action,Adventure,Drama'),
#  (72, 'tt6027920', 'tvEpisode', 'The Iron Throne', 'The Iron Throne', 0, 2019, '\\N', 80, 'Action,Adventure,Drama')]

# %%
df = pandas.read_csv("../data/IMDB/name_basics.csv")
df.to_sql("got_title_basics", schema="s25_project", con=default_engine, index=False, if_exists="replace")
# Out:
# 351

# %%
# %sql use s25_project
# %sql select * from got_title_basics
# Out:
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 0 rows affected.
#  * mysql+pymysql://root:***@localhost?local_infile=1
# 351 rows affected.
# [('nm0389698', 'B.J. Hogg', 'actor,music_department', 'tt0986233,tt1240982,tt0970411,tt0944947', 'B.J.', 'Hogg', None, None, None, None, 1955.0, 2020.0),
#  ('nm0269923', 'Michael Feast', 'actor,composer,soundtrack', 'tt0120879,tt0472160,tt0362192,tt0810823', 'Michael', 'Feast', None, None, None, None, 1946.0, None),
#  ('nm0727778', 'David Rintoul', 'actor,archive_footage', 'tt1139328,tt4786824,tt6079772,tt1007029', 'David', 'Rintoul', None, None, None, None, 1948.0, None),
#  ('nm6729880', 'Chuku Modu', 'actor,writer,producer', 'tt4154664,tt2674426,tt0944947,tt6470478', 'Chuku', 'Modu', None, None, None, None, 1990.0, None),
#  ('nm0853583', 'Owen Teale', 'actor,writer,archive_footage', 'tt0102797,tt0944947,tt0485301,tt0462396', 'Owen', 'Teale', None, None, None, None, 1961.0, None),
#  ('nm0203801', 'Karl Davies', 'actor,producer', 'tt3428912,tt7366338,tt0944947,tt12879632', 'Karl', 'Davies', None, None, None, None, 1982.0, None),
#  ('nm8257864', 'Megan Parkinson', 'actress,director,writer', 'tt0944947,tt26934073,tt4276618,tt6636246', 'Megan', 'Parkinson', None, None, None, None, None, None),
#  ('nm0571654', 'Fintan McKeown', 'actor', 'tt0112178,tt0110116,tt0166396,tt0944947', 'Fintan', 'McKeown', None, None, None, None, None, None),
#  ('nm1528121', 'Philip McGinley', 'actor,archive_footage', 'tt0944947,tt1446714,tt0053494,tt4015216', 'Philip', 'McGinley', None, None, None, None, 1981.0, None),
#  ('nm0000980', 'Jim Broadbent', 'actor,writer,producer', 'tt0203009,tt1431181,tt1007029,tt0425112', 'Jim', 'Broadbent', None, None, None, None, 1949.0, None),
#  ('nm0649046', 'Deobia Oparei', 'actor,archive_footage', 'tt1343727,tt0419706,tt0118929,tt0203009', 'Deobia', 'Oparei', None, None, None, None, 1971.0, None),
#  ('nm1783582', 'Sahara Knite', 'actress,archive_footage', 'tt0944947,tt9814116,tt15249564,tt15288590', 'Sahara', 'Knite', None, None, None, None, 1975.0, None),
#  ('nm8127149', 'Nathanael Saleh', 'actor,soundtrack', 'tt5028340,tt0944947,tt1635327,tt3498954', 'Nathanael', 'Saleh', None, None, None, None, None, None),
#  ('nm1074361', 'Luke Roberts', 'actor,producer,composer', 'tt5809150,tt2375692,tt0944947,tt1877830', 'Luke', 'Roberts', None, None, None, None, 1977.0, None),
#  ('nm3586035', 'Maisie Williams', 'actress,producer,soundtrack', 'tt4682266,tt0944947,tt3294200,tt1330018', 'Maisie', 'Williams', None, None, None, None, 1997.0, None),
#  ('nm0538869', 'Patrick Malahide', 'actor,writer,producer', 'tt0116908,tt0143145,tt0090521,tt0120873', 'Patrick', 'Malahide', None, None, None, None, 1945.0, None),
#  ('nm4207240', 'Phil Barnhill', 'actor', 'tt1785299', 'Phil', 'Barnhill', None, None, None, None, None, None),
#  ('nm0568400', 'Ian McElhinney', 'actor,director,soundtrack', 'tt0116477,tt0944947,tt3748528,tt0970411', 'Ian', 'McElhinney', None, None, None, None, 1948.0, None),
#  ('nm1152798', 'Joseph Mawle', 'actor,archive_footage', 'tt0944947,tt1127876,tt1390411,tt2183641', 'Joseph', 'Mawle', None, None, None, None, 1974.0, None),
#  ('nm4730958', 'Eline Powell', 'actress,director,writer', 'tt2091298,tt1972591,tt2884308,tt0944947', 'Eline', 'Powell', None, None, None, None, 1990.0, None),
#  ('nm0429956', 'Gerard Jordan', 'actor', 'tt2614684,tt1238291,tt0944947,tt2294189', 'Gerard', 'Jordan', None, None, None, None, None, None),
#  ('nm1978998', 'Forbes KB', 'actor,transportation_department,sound_department', 'tt1289406,tt0381061,tt0436697,tt0866439', 'Forbes', 'KB', None, None, None, None, 1965.0, None),
#  ('nm1043031', 'Tim Plester', 'actor,director,producer', 'tt8398600,tt0944947,tt1727824,tt1702622', 'Tim', 'Plester', None, None, None, None, 1970.0, None),
#  ('nm5279916', 'Leigh Gill', 'actor,miscellaneous', 'tt7286456,tt11315808,tt3183660,tt0944947', 'Leigh', 'Gill', None, None, None, None, None, None),
#  ('nm1638006', 'Michael Condron', 'actor', 'tt0053494,tt0944947,tt8103066,tt30422469', 'Michael', 'Condron', None, None, None, None, None, None),
#  ('nm3652842', 'Isaac Hempstead Wright', 'actor,soundtrack,archive_footage', 'tt0787474,tt0944947,tt1687901,tt9664108', 'Isaac', 'Wright', 'Hempstead', None, None, None, 1999.0, None),
#  ('nm5106314', 'Gemita Samarra', 'stunts,actress,director', 'tt2379713,tt0944947,tt1355631,tt1935859', 'Gemita', 'Samarra', None, None, None, None, None, None),
#  ('nm3729225', 'Gwendoline Christie', 'actress,casting_department,producer', 'tt0944947,tt2527336,tt2488496,tt1951266', 'Gwendoline', 'Christie', None, None, None, None, 1978.0, None),
#  ('nm0283492', 'Jerome Flynn', 'actor,producer,soundtrack', 'tt0944947,tt2085059,tt6146586,tt2183641', 'Jerome', 'Flynn', None, None, None, None, 1963.0, None),
#  ('nm0574534', 'Ian McShane', 'actor,producer,director', 'tt0348914,tt1298650,tt1735898,tt0441773', 'Ian', 'McShane', None, None, None, None, 1942.0, None),
#  ('nm0751085', 'Clive Russell', 'actor,soundtrack,archive_footage', 'tt0988045,tt0780653,tt0349683,tt0115288', 'Clive', 'Russell', None, None, None, None, 1945.0, None),
#  ('nm1214477', 'Michael Grennell', 'actor,archive_footage', 'tt0944947,tt2183641,tt0264333,tt0198209', 'Michael', 'Grennell', None, None, None, None, 1958.0, None),
#  ('nm0265610', 'Michelle Fairley', 'actress,archive_footage', 'tt0944947,tt2431286,tt1390411,tt0926084', 'Michelle', 'Fairley', None, None, None, None, 1963.0, None),
#  ('nm0734498', 'Lalor Roddy', 'actor', 'tt1525366,tt0986233,tt6793280,tt1248971', 'Lalor', 'Roddy', None, None, None, None, 1954.0, None),
#  ('nm0372176', 'Lena Headey', 'actress,producer,director', 'tt0416449,tt0944947,tt1374989,tt1343727', 'Lena', 'Headey', None, None, None, None, 1973.0, None),
#  ('nm2456829', 'Alice Hewkin', 'actress,soundtrack', 'tt3778644,tt2345759,tt0944947,tt17632862', 'Alice', 'Hewkin', None, None, None, None, None, None),
#  ('nm0404809', 'Frank Hvam', 'actor,writer,producer', 'tt1680136,tt0434695,tt0272993,tt0270762', 'Frank', 'Hvam', None, None, None, None, 1970.0, None),
#  ('nm4007028', 'Darren Killeen', 'actor', 'tt0944947,tt5447862,tt2244875,tt7162514', 'Darren', 'Killeen', None, None, None, None, None, None),
#  ('nm0700059', 'Robert Pugh', 'actor,writer,director', 'tt1139328,tt0311113,tt0955308,tt0320661', 'Robert', 'Pugh', None, None, None, None, 1950.0, None),
#  ('nm3592338', 'Emilia Clarke', 'actress,producer,soundtrack', 'tt0944947,tt1340138,tt2674426,tt3778644', 'Emilia', 'Clarke', None, None, None, None, 1986.0, None),
#  ('nm0408591', 'Ralph Ineson', 'actor,producer,soundtrack', 'tt4263482,tt9243804,tt11858890,tt6412452', 'Ralph', 'Ineson', None, None, None, None, 1969.0, None),
#  ('nm3996678', 'Maisie Dee', 'actress,archive_footage', 'tt0944947,tt13306176,tt22940408,tt4389976', 'Maisie', 'Dee', None, None, None, None, 1985.0, None),
#  ('nm0192377', 'Liam Cunningham', 'actor,director,producer', 'tt0986233,tt0460989,tt0800320,tt0944947', 'Liam', 'Cunningham', None, None, None, None, 1961.0, None),
#  ('nm1613839', 'Ian Whyte', 'actor,miscellaneous,stunts', 'tt9253284,tt0944947,tt1446714,tt11138512', 'Ian', 'Whyte', None, None, None, None, 1971.0, None),
#  ('nm1368037', 'Alisdair Simpson', 'actor', 'tt0944947,tt0259733,tt2368254,tt0372091', 'Alisdair', 'Simpson', None, None, None, None, None, None),
#  ('nm0915453', 'Tony Way', 'actor,writer,director', 'tt1631867,tt1568346,tt0462335,tt2717860', 'Tony', 'Way', None, None, None, None, 1978.0, None),
#  ('nm0796502', 'Alexander Siddig', 'actor,director,soundtrack', 'tt0106145,tt0320661,tt0253556,tt0190865', 'Alexander', 'Siddig', None, None, None, None, 1965.0, None),
#  ('nm1861467', 'Roxanne McKee', 'actress', 'tt0944947,tt3079768,tt1043726,tt0112004', 'Roxanne', 'McKee', None, None, None, None, None, None),
#  ('nm6088160', 'Diogo Sales', 'actor', 'tt0944947,tt21867228,tt6353166,tt17677434', 'Diogo', 'Sales', None, None, None, None, None, None),
#  ('nm2999602', 'Junade Khan', 'actor', 'tt0944947,tt0112004,tt0259733,tt6809036', 'Junade', 'Khan', None, None, None, None, None, None),
#  ('nm2231505', 'David James Coakley', 'actor,writer', 'tt0944947,tt1672189,tt6632666,tt12343858', 'David', 'Coakley', 'James', None, None, None, None, None),
#  ('nm0752638', 'Jonathan Ryan', 'actor', 'tt0105112,tt0877105,tt0107207,tt0944947', 'Jonathan', 'Ryan', None, None, None, None, None, None),
#  ('nm0000293', 'Sean Bean', 'actor,producer,animation_department', 'tt0120737,tt0944947,tt1181791,tt0167261', 'Sean', 'Bean', None, None, None, None, 1959.0, None),
#  ('nm0174005', 'Ben Crompton', 'actor,director,producer', 'tt1788391,tt0944947,tt0211181,tt2235695', 'Ben', 'Crompton', None, None, None, None, 1974.0, None),
#  ('nm0580014', 'Tobias Menzies', 'actor,writer,soundtrack', 'tt16912512,tt15771916,tt4786824,tt3006802', 'Tobias', 'Menzies', None, None, None, None, 1974.0, None),
#  ('nm0890055', 'Indira Varma', 'actress,producer,archive_footage', 'tt3763912,tt0361411,tt9603212,tt0384766', 'Indira', 'Varma', None, None, None, None, 1973.0, None),
#  ('nm4473207', 'Barrington Cullen', 'actor', 'tt0944947,tt14527610,tt4557078,tt3480948', 'Barrington', 'Cullen', None, None, None, None, None, None),
#  ('nm1561982', 'Pilou Asbæk', 'actor,miscellaneous,soundtrack', 'tt1219827,tt4530422,tt0944947,tt2216240', 'Pilou', 'Asbæk', None, None, None, None, 1982.0, None),
#  ('nm2406775', 'Cedric Henderson', 'actor', 'tt0944947,tt0807980,tt8561820', 'Cedric', 'Henderson', None, None, None, None, None, None),
#  ('nm0050520', 'Peter Ballance', 'actor,miscellaneous', 'tt0944947,tt1985443,tt3223394,tt0408056', 'Peter', 'Ballance', None, None, None, None, None, None),
#  ('nm0443825', 'Dermot Keaney', 'actor,archive_footage', 'tt0383574,tt0449088,tt1020558,tt0110428', 'Dermot', 'Keaney', None, None, None, None, 1964.0, None),
#  ('nm2307468', 'Ricky Champ', 'actor,archive_footage', 'tt1213663,tt3045616,tt0944947,tt1974934', 'Ricky', 'Champ', None, None, None, None, 1980.0, None),
#  ('nm1478079', 'Joe Dempsie', 'actor,soundtrack,archive_footage', 'tt0840196,tt0944947,tt1297919,tt1935302', 'Joe', 'Dempsie', None, None, None, None, 1987.0, None),
#  ('nm6793798', 'Eddie Eyre', 'actor,miscellaneous,set_decorator', 'tt0944947,tt5809150,tt0088512,tt8785372', 'Eddie', 'Eyre', None, None, None, None, 1988.0, None),
#  ('nm2356940', 'Hannah Murray', 'actress,soundtrack,archive_footage', 'tt2141751,tt4180576,tt0944947,tt5390504', 'Hannah', 'Murray', None, None, None, None, 1989.0, None),
#  ('nm3354768', 'Alan Paris', 'actor', 'tt1186830,tt0944947,tt13592494,tt2825222', 'Alan', 'Paris', None, None, None, None, None, None),
#  ('nm0130538', 'Sam Callis', 'actor,writer,producer', 'tt3633218,tt1727309,tt0944947,tt0334874', 'Sam', 'Callis', None, None, None, None, 1973.0, None),
#  ('nm2089809', 'Nikovich Sammut', 'stunts,actor,miscellaneous', 'tt0408306,tt4172430,tt1270262,tt1186830', 'Nikovich', 'Sammut', None, None, None, None, None, None),
#  ('nm4440118', 'Seamus Kelly', 'actor,stunts', 'tt0944947', 'Seamus', 'Kelly', None, None, None, None, None, None),
#  ('nm0002103', 'Julian Glover', 'actor,soundtrack,archive_footage', 'tt0097576,tt0080684,tt0082398,tt0332452', 'Julian', 'Glover', None, None, None, None, 1935.0, None),
#  ('nm0798872', 'Peter Silverleaf', 'actor', 'tt2537176,tt0119115,tt0944947,tt0096555', 'Peter', 'Silverleaf', None, None, None, None, None, None),
#  ('nm7318132', 'Davor Jozinovic', 'actor', 'tt0944947', 'Davor', 'Jozinovic', None, None, None, None, None, None),
#  ('nm3005802', 'Ivan Peric', 'actor,editor,miscellaneous', 'tt1877832,tt2139881,tt2295560,tt6866224', 'Ivan', 'Peric', None, None, None, None, None, None),
#  ('nm7318134', 'Hadi Kermani', 'actor', 'tt0944947,tt3295330,tt11083482', 'Hadi', 'Kermani', None, None, None, None, None, None),
#  ('nm7318135', 'Tonci Banov', 'actor', 'tt0944947,tt5061784', 'Tonci', 'Banov', None, None, None, None, None, None),
#  ('nm0544139', 'Clive Mantle', 'actor,writer,archive_footage', 'tt0103644,tt0096454,tt0944947,tt1475582', 'Clive', 'Mantle', None, None, None, None, 1957.0, None),
#  ('nm0057965', 'Clifford Barry', 'actor,miscellaneous', 'tt0189192,tt0944947,tt0094535,tt0118363', 'Clifford', 'Barry', None, None, None, None, None, None),
#  ('nm4440305', 'Mark Stanley', 'actor,soundtrack', 'tt8365002,tt7334158,tt5700176,tt3622120', 'Mark', 'Stanley', None, None, None, None, 1988.0, None),
#  ('nm2760664', 'Jacob Anderson', 'actor,soundtrack', 'tt0944947,tt4530422,tt1514041,tt3960394', 'Jacob', 'Anderson', None, None, None, None, 1990.0, None),
#  ('nm0234541', 'Roy Dotrice', 'actor,writer,archive_footage', 'tt0411477,tt0086879,tt0092319,tt0104040', 'Roy', 'Dotrice', None, None, None, None, 1923.0, 2017.0),
#  ('nm6301068', 'Sabrina Bartlett', 'actress', 'tt0944947,tt3874450,tt8740790,tt3636060', 'Sabrina', 'Bartlett', None, None, None, None, 1991.0, None),
#  ('nm2407387', 'Sara Dylan', 'actress', 'tt0944947,tt0981330,tt2303687,tt4276624', 'Sara', 'Dylan', None, None, None, None, None, None),
#  ('nm1051151', 'Paul Rattray', 'actor', 'tt0381966,tt0157583,tt0944947,tt1127876', 'Paul', 'Rattray', None, None, None, None, None, None),
#  ('nm4704928', 'Marc Rissmann', 'actor,director,writer', 'tt0944947,tt1740299,tt4179452,tt13991232', 'Marc', 'Rissmann', None, None, None, None, None, None),
#  ('nm0267256', 'Souad Faress', 'actress,archive_footage', 'tt1160419,tt4575576,tt1473832,tt0944947', 'Souad', 'Faress', None, None, None, None, None, None),
#  ('nm0894857', 'David Verrey', 'actor,archive_footage', 'tt0317198,tt13287846,tt0944947,tt0436992', 'David', 'Verrey', None, None, None, None, None, None),
#  ('nm0072855', 'Paul Bentley', 'actor', 'tt1007029,tt0944947,tt0185906,tt8697870', 'Paul', 'Bentley', None, None, None, None, None, None),
#  ('nm0000596', 'Jonathan Pryce', 'actor,producer,soundtrack', 'tt8404614,tt0088846,tt0120347,tt3750872', 'Jonathan', 'Pryce', None, None, None, None, 1947.0, None),
#  ('nm2181128', 'Joel Fry', 'actor,writer,producer', 'tt8079248,tt0944947,tt3228774,tt0443649', 'Joel', 'Fry', None, None, None, None, 1985.0, None),
#  ('nm3964231', 'Kristian Nairn', 'actor,producer,archive_sound', 'tt0944947,tt2183641,tt6857040,tt11000902', 'Kristian', 'Nairn', None, None, None, None, 1975.0, None),
#  ('nm0628040', 'Christopher Newman', 'producer,assistant_director,miscellaneous', 'tt0944947,tt0185906,tt0107943,tt0120915', 'Christopher', 'Newman', None, None, None, None, None, None),
#  ('nm3444954', 'Ben Hawkey', 'actor', 'tt1562871,tt0944947,tt1371160,tt1919418', 'Ben', 'Hawkey', None, None, None, None, None, None),
#  ('nm4547262', 'Leo Woodruff', 'stunts,actor', 'tt2382320,tt1211837,tt1345836,tt1735898', 'Leo', 'Woodruff', None, None, None, None, None, None),
#  ('nm2131630', 'Jefferson Hall', 'actor,producer,archive_footage', 'tt6723592,tt15398776,tt1502407,tt2488496', 'Jefferson', 'Hall', None, None, None, None, 1977.0, None),
#  ('nm0019885', 'Roger Allam', 'actor,producer,soundtrack', 'tt0434409,tt0811080,tt0460989,tt1298650', 'Roger', 'Allam', None, None, None, None, 1953.0, None),
#  ('nm3330122', 'Wilko Johnson', 'actor,soundtrack,archive_footage', 'tt0944947,tt1738634,tt4188192,tt1245412', 'Wilko', 'Johnson', None, None, None, None, 1947.0, 2022.0),
#  ('nm3822505', 'Amrita Acharia', 'actress,director,writer', 'tt14022350,tt0944947,tt10642480,tt2798170', 'Amrita', 'Acharia', None, None, None, None, None, None),
#  ('nm0001290', 'Richard E. Grant', 'actor,director,writer', 'tt0280707,tt4595882,tt0102070,tt17351924', 'Richard', 'Grant', 'E.', None, None, None, 1957.0, None),
#  ('nm4781280', 'Paul Caddell', 'actor,director,writer', 'tt0944947,tt4885624,tt1248971,tt2294189', 'Paul', 'Caddell', None, None, None, None, None, None),
#  ('nm0182666', 'Nikolaj Coster-Waldau', 'actor,producer,writer', 'tt0944947,tt1483013,tt2404233,tt0110631', 'Nikolaj', 'Coster-Waldau', None, None, None, None, 1970.0, None),
#  ('nm0141582', 'Dominic Carter', 'actor,archive_footage', 'tt0944947,tt0493383,tt0053494,tt2088544', 'Dominic', 'Carter', None, None, None, None, None, None),
#  ('nm0937239', 'Tom Wlaschiha', 'actor,archive_footage', 'tt0944947,tt2427220,tt1391116,tt2473794', 'Tom', 'Wlaschiha', None, None, None, None, 1973.0, None),
#  ('nm0641433', "Patrick O'Kane", 'actor', 'tt2527336,tt0204313,tt5116280,tt0319938', 'Patrick', "O'Kane", None, None, None, None, 1965.0, None),
#  ('nm4475335', "Jeffrey O'Brien", 'actor', 'tt0829150,tt0944947,tt2653350', 'Jeffrey', "O'Brien", None, None, None, None, None, None),
#  ('nm0181920', 'James Cosmo', 'actor,producer,soundtrack', 'tt0112573,tt0091203,tt0332452,tt0363771', 'James', 'Cosmo', None, None, None, None, 1948.0, None),
#  ('nm4424689', 'Sarita Piotrowski', 'actress,miscellaneous', 'tt0944947,tt2476682,tt2214815,tt1682886', 'Sarita', 'Piotrowski', None, None, None, None, None, None),
#  ('nm0322416', 'Jack Gleeson', 'actor,archive_footage', 'tt0944947,tt0372784,tt1014774,tt15782690', 'Jack', 'Gleeson', None, None, None, None, 1992.0, None),
#  ('nm1032473', 'Thomas Brodie-Sangster', 'actor,producer,soundtrack', 'tt4046784,tt1790864,tt0314331,tt4500922', 'Thomas', 'Brodie-Sangster', None, None, None, None, 1990.0, None),
#  ('nm0822062', 'John Standing', 'actor,soundtrack,archive_footage', 'tt0434409,tt0080678,tt0457513,tt0074452', 'John', 'Standing', None, None, None, None, 1934.0, None),
#  ('nm3229685', 'Kit Harington', 'actor,writer,producer', 'tt0944947,tt1921064,tt0938330,tt9032400', 'Kit', 'Harington', None, None, None, None, 1986.0, None),
#  ('nm0639569', "Gerry O'Brien", 'actor,archive_footage', 'tt0253556,tt0312549,tt0349683,tt0383574', 'Gerry', "O'Brien", None, None, None, None, 1949.0, None),
#  ('nm0322513', 'Iain Glen', 'actor,producer,soundtrack', 'tt0944947,tt6954652,tt10370380,tt6859806', 'Iain', 'Glen', None, None, None, None, 1961.0, None),
#  ('nm0803397', 'Jamie Sives', 'actor,producer,director', 'tt0329767,tt0862467,tt0291341,tt1226229', 'Jamie', 'Sives', None, None, None, None, 1973.0, None),
#  ('nm4958677', 'Kelly Long', 'art_department,actress,assistant_director', 'tt4178092,tt0944947,tt7012634,tt29767038', 'Kelly', 'Long', None, None, None, None, None, None),
#  ('nm1218607', 'Burn Gorman', 'actor,soundtrack,archive_footage', 'tt2049403,tt1488589,tt2557478,tt1345836', 'Burn', 'Gorman', None, None, None, None, 1974.0, None),
#  ('nm2171898', 'Birgitte Hjort Sørensen', 'actress,soundtrack', 'tt1971325,tt2675914,tt1961192,tt2848292', 'Birgitte', 'Sørensen', 'Hjort', None, None, None, 1982.0, None),
#  ('nm4768858', 'Pixie Le Knot', 'actress,miscellaneous,stunts', 'tt0944947,tt2388771,tt1560985,tt3726322', 'Pixie', 'Le Knot', None, None, None, None, None, None),
#  ('nm2461009', 'Tim Landers', 'actor', 'tt0944947,tt15782690,tt21957774,tt15346418', 'Tim', 'Landers', None, None, None, None, None, None),
#  ('nm0312245', 'Ian Gelder', 'actor', 'tt0485301,tt0944947,tt0458455,tt0420932', 'Ian', 'Gelder', None, None, None, None, 1949.0, 2024.0),
#  ('nm0597388', 'Jason Momoa', 'actor,producer,writer', 'tt1477834,tt9663764,tt4334266,tt0974015', 'Jason', 'Momoa', None, None, None, None, 1979.0, None),
#  ('nm0622533', 'Joseph Naufahu', 'actor', 'tt1219827,tt1442449,tt0944947,tt1386958', 'Joseph', 'Naufahu', None, None, None, None, 1978.0, None),
#  ('nm3040811', 'Andrei Claude', 'actor', 'tt0944947,tt2306299,tt5057130,tt12610390', 'Andrei', 'Claude', None, None, None, None, 1979.0, None),
#  ('nm0341739', 'Raymond Griffiths', 'actor,miscellaneous', 'tt0120915,tt0944947,tt0379670,tt0472071', 'Raymond', 'Griffiths', None, None, None, None, None, None),
#  ('nm2482781', 'Dean Whatton', 'actor', 'tt0944947,tt3474788,tt2792326,tt1983079', 'Dean', 'Whatton', None, None, None, None, None, None),
#  ('nm3338062', 'George Appleby', 'actor,stunts', 'tt0944947,tt5257554,tt7035992,tt14407126', 'George', 'Appleby', None, None, None, None, None, None),
#  ('nm3453345', 'Maxwell Laird', 'actor', 'tt1582196,tt0944947,tt1305562,tt2215211', 'Maxwell', 'Laird', None, None, None, None, None, None),
#  ('nm1168404', 'Reg Wayment', 'stunts,actor,miscellaneous', 'tt0451279,tt1074638,tt0440963,tt3480822', 'Reg', 'Wayment', None, None, None, None, None, None),
#  ('nm0432837', 'Marko Juraga', 'actor,sound_department,composer', 'tt0944947,tt0102236,tt0376909,tt14895146', 'Marko', 'Juraga', None, None, None, None, 1984.0, None),
#  ('nm5037688', 'Rea Separovic', 'actress', 'tt0944947', 'Rea', 'Separovic', None, None, None, None, None, None),
#  ('nm0119804', 'Ania Bukstein', 'actress,soundtrack,archive_footage', 'tt3602528,tt0944947,tt5673782,tt6965662', 'Ania', 'Bukstein', None, None, None, None, 1982.0, None),
#  ('nm8314450', 'Lucy Hayes', 'actress', 'tt0944947', 'Lucy', 'Hayes', None, None, None, None, None, None),
#  ('nm3122423', 'Patrick Ryan', 'actor', 'tt0944947,tt4320944,tt14527610,tt11311302', 'Patrick', 'Ryan', None, None, None, None, None, None),
#  ('nm0734304', 'Paddy Rocks', 'actor', 'tt2567712,tt0944947,tt0127516,tt2326204', 'Paddy', 'Rocks', None, None, None, None, None, None),
#  ('nm0170799', 'Steven Cole', 'actor', 'tt0944947,tt0083392', 'Steven', 'Cole', None, None, None, None, None, None),
#  ('nm0383835', 'Dan Hildebrand', 'actor,miscellaneous,cinematographer', 'tt0187078,tt0944947,tt1124373,tt5165412', 'Dan', 'Hildebrand', None, None, None, None, None, None),
#  ('nm4450657', 'Kevin Keenan', 'actor', 'tt0944947,tt2190796,tt2943206,tt3635702', 'Kevin', 'Keenan', None, None, None, None, None, None),
#  ('nm0204583', 'Essie Davis', 'actress,producer,soundtrack', 'tt2321549,tt2094766,tt4844140,tt9010738', 'Essie', 'Davis', None, None, None, None, 1970.0, None),
#  ('nm1638294', 'Eugene Simon', 'actor,producer', 'tt0944947,tt1638319,tt7583274,tt4399952', 'Eugene', 'Simon', None, None, None, None, 1992.0, None),
#  ('nm0174449', 'Aiden Condron', 'actor', 'tt0120815,tt0944947,tt0120865,tt1376713', 'Aiden', 'Condron', None, None, None, None, None, None),
#  ('nm0481924', 'Richard Laing', 'actor', 'tt0944947,tt3110958,tt3923662', 'Richard', 'Laing', None, None, None, None, None, None),
#  ('nm1406364', 'Conor Delaney', 'actor', 'tt0944947,tt0283096,tt0488121,tt3344708', 'Conor', 'Delaney', None, None, None, None, None, None),
#  ('nm4492930', 'Simon Stewart', 'actor', 'tt0944947,tt2544624,tt6363592', 'Simon', 'Stewart', None, None, None, None, None, None),
#  ('nm3292422', 'Chris Gallagher', 'actor', 'tt0944947,tt2306299,tt1565785,tt0170930', 'Chris', 'Gallagher', None, None, None, None, None, None),
#  ('nm5908524', 'Christian Vit', 'actor,producer', 'tt11311302,tt0944947,tt14449470,tt7491982', 'Christian', 'Vit', None, None, None, None, None, None),
#  ('nm1778512', 'Jóhannes Haukur Jóhannesson', 'actor,sound_department', 'tt11311302,tt7660850,tt10569934,tt0944947', 'Jóhannes', 'Jóhannesson', 'Haukur', None, None, None, 1980.0, None),
#  ('nm0564516', 'Vinnie McCabe', 'actor,producer', 'tt0117039,tt0944947,tt0114307,tt14357986', 'Vinnie', 'McCabe', None, None, None, None, None, None),
#  ('nm3330066', 'Sarine Sofair', 'actress,production_manager', 'tt1781769,tt5312104,tt0944947,tt2262287', 'Sarine', 'Sofair', None, None, None, None, None, None),
#  ('nm6537691', 'Samuel Paul Small', 'actor', 'tt0944947,tt16437278,tt12209830,tt21819258', 'Samuel', 'Small', 'Paul', None, None, None, None, None),
#  ('nm4475204', 'Tristan Mercieca', 'actor', 'tt0944947', 'Tristan', 'Mercieca', None, None, None, None, None, None),
#  ('nm8127150', 'Michael Nevin', 'actor', 'tt0944947,tt5882386', 'Michael', 'Nevin', None, None, None, None, None, None),
#  ('nm8127151', 'Jesse Magee', 'actor', 'tt0944947,tt6036728,tt1983079', 'Jesse', 'Magee', None, None, None, None, None, None),
#  ('nm8133415', 'Iona Clarke', 'actress', 'tt0944947,tt6793280', 'Iona', 'Clarke', None, None, None, None, None, None),
#  ('nm8127152', 'Lucy Gallagher', 'actress', 'tt0944947,tt6651118', 'Lucy', 'Gallagher', None, None, None, None, None, None),
#  ('nm6462692', 'Fionn Kernan', 'actor', 'tt0944947,tt2465408', 'Fionn', 'Kernan', None, None, None, None, None, None),
#  ('nm1707712', 'Zachary Baharov', 'actor,producer,archive_footage', 'tt1023114,tt1288403,tt1909015,tt9603212', 'Zachary', 'Baharov', None, None, None, None, 1980.0, None),
#  ('nm0852965', 'Noah Taylor', 'actor,script_department,soundtrack', 'tt0181875,tt0362270,tt0117631,tt2397535', 'Noah', 'Taylor', None, None, None, None, 1969.0, None),
#  ('nm5502252', 'Elizabeth Cadwallader', 'actress', 'tt0944947,tt7526498,tt0096555,tt11824218', 'Elizabeth', 'Cadwallader', None, None, None, None, None, None),
#  ('nm2869309', 'Eros V', 'actor,director,writer', 'tt30835426,tt8877172,tt11758780', 'Eros', 'V', None, None, None, None, 1995.0, None),
#  ('nm3645691', 'Finn Jones', 'actor,archive_footage', 'tt10418662,tt3322310,tt0944947,tt2620590', 'Finn', 'Jones', None, None, None, None, 1988.0, None),
#  ('nm5651524', 'Mark Coney', 'actor', 'tt3414054,tt3244986,tt0758790,tt1233560', 'Mark', 'Coney', None, None, None, None, None, None),
#  ('nm1101680', 'Gordon Fulton', 'actor', 'tt0944947,tt5116280,tt3101352,tt0465670', 'Gordon', 'Fulton', None, None, None, None, 1949.0, 2016.0),
#  ('nm0384152', 'Conleth Hill', 'actor,writer,producer', 'tt0944947,tt1178663,tt5075662,tt1441952', 'Conleth', 'Hill', None, None, None, None, 1964.0, None),
#  ('nm0641596', "Jer O'Leary", 'actor', 'tt0117039,tt0107207,tt0298845,tt0097937', 'Jer', "O'Leary", None, None, None, None, 1945.0, 2018.0),
#  ('nm3524836', 'Steve Cash', 'talent_agent,executive,actor', 'tt0944947,tt2306299,tt2183641,tt1695366', 'Steve', 'Cash', None, None, None, None, None, None),
#  ('nm6342915', 'Robert Fawsitt', 'actor', 'tt1212428,tt0944947,tt2306299,tt3865236', 'Robert', 'Fawsitt', None, None, None, None, None, None),
#  ('nm8165602', 'Bella Ramsey', 'actress,soundtrack,writer', 'tt0944947,tt3581920,tt11727866,tt6385540', 'Bella', 'Ramsey', None, None, None, None, 2003.0, None),
#  ('nm4957233', 'Aisling Franciosi', 'actress,soundtrack', 'tt14852624,tt27534307,tt4068576,tt10375396', 'Aisling', 'Franciosi', None, None, None, None, None, None),
#  ('nm0225483', 'Kate Dickie', 'actress,producer,archive_footage', 'tt0471030,tt1446714,tt1450321,tt9243804', 'Kate', 'Dickie', None, None, None, None, 1971.0, None),
#  ('nm0004355', 'Roger Ashton-Griffiths', 'actor,writer,director', 'tt0944947,tt4575576,tt0088846,tt0217505', 'Roger', 'Ashton-Griffiths', None, None, None, None, 1957.0, None),
#  ('nm0891092', 'Peter Vaughan', 'actor,soundtrack,archive_footage', 'tt0067800,tt0088846,tt0795368,tt0081633', 'Peter', 'Vaughan', None, None, None, None, 1923.0, 2016.0),
#  ('nm0203882', 'Oliver Ford Davies', 'actor,archive_footage', 'tt0120915,tt7322224,tt0121765,tt0274166', 'Oliver', 'Davies', 'Ford', None, None, None, 1939.0, None),
#  ('nm0838910', 'Donald Sumpter', 'actor,archive_footage', 'tt1390411,tt0387131,tt1568346,tt0765443', 'Donald', 'Sumpter', None, None, None, None, 1943.0, None),
#  ('nm1483416', 'Richard Rycroft', 'actor', 'tt0944947,tt1473832,tt4786824,tt23468836', 'Richard', 'Rycroft', None, None, None, None, None, None),
#  ('nm2807170', 'Neil Fingleton', 'actor,stunts,miscellaneous', 'tt1270798,tt1335975,tt2395427,tt1617661', 'Neil', 'Fingleton', None, None, None, None, 1980.0, 2017.0),
#  ('nm0562003', 'Jodhi May', 'actress,director,writer', 'tt0104691,tt0111205,tt0096464,tt0129111', 'Jodhi', 'May', None, None, None, None, 1975.0, None),
#  ('nm2162079', 'Ivailo Dimitrov', 'stunts,actor', 'tt6998518,tt0816711,tt3062096,tt12844910', 'Ivailo', 'Dimitrov', None, None, None, None, None, None),
#  ('nm4982614', 'Dennis Stokes', 'actor', 'tt0944947', 'Dennis', 'Stokes', None, None, None, None, None, None),
#  ('nm0015382', 'Adewale Akinnuoye-Agbaje', 'actor,director,writer', 'tt1127881', 'Adewale', 'Akinnuoye-Agbaje', None, None, None, None, 1967.0, None),
#  ('nm0001354', 'Ciarán Hinds', 'actor,soundtrack,archive_footage', 'tt12789558,tt1596365,tt1340800,tt1201607', 'Ciarán', 'Hinds', None, None, None, None, 1953.0, None),
#  ('nm0243696', 'James Doran', 'actor', 'tt2567712,tt0944947,tt1097643,tt0116379', 'James', 'Doran', None, None, None, None, None, None),
#  ('nm6442298', 'Conor Watters', 'actor', 'tt0944947', 'Conor', 'Watters', None, None, None, None, None, None),
#  ('nm4982706', 'Josephine Gillan', 'actress', 'tt0944947,tt3004644,tt9455188', 'Josephine', 'Gillan', None, None, None, None, 1988.0, None),
#  ('nm1754059', 'Natalie Dormer', 'actress,producer,writer', 'tt0944947,tt0758790,tt1951266,tt10361016', 'Natalie', 'Dormer', None, None, None, None, 1982.0, None),
#  ('nm2983094', 'Aisling Jarrett-Gavin', 'actress', 'tt0944947,tt1215172,tt8001226,tt1999642', 'Aisling', 'Jarrett-Gavin', None, None, None, None, None, None),
#  ('nm2047170', 'Emun Elliott', 'actor', 'tt2488496,tt1446714,tt1450321,tt0944947', 'Emun', 'Elliott', None, None, None, None, 1983.0, None),
#  ('nm2835616', 'Dean-Charles Chapman', 'actor,archive_footage', 'tt8579674,tt1726592,tt8266310,tt0944947', 'Dean-Charles', 'Chapman', None, None, None, None, 1997.0, None),
#  ('nm3126053', 'Susie Kelly', 'actress', 'tt1240982,tt0944947,tt0985593,tt0488380', 'Susie', 'Kelly', None, None, None, None, None, None),
#  ('nm4523680', 'Kerr Logan', 'actor', 'tt1034007,tt4276618,tt11403434,tt0944947', 'Kerr', 'Logan', None, None, None, None, 1988.0, None),
#  ('nm1697771', 'Ellie Kendrick', 'actress,writer,soundtrack', 'tt1174732,tt1159922,tt5158522,tt0944947', 'Ellie', 'Kendrick', None, None, None, None, 1990.0, None),
#  ('nm2911170', 'Laurence Doherty', 'actor,writer', 'tt2145829,tt12723964,tt1253869,tt1333064', 'Laurence', 'Doherty', None, None, None, None, None, None),
#  ('nm0819087', 'Samantha Spiro', 'actress,archive_footage', 'tt2674426,tt0120681,tt0228157,tt7767422', 'Samantha', 'Spiro', None, None, None, None, 1968.0, None),
#  ('nm0396924', 'Carice van Houten', 'actress,producer,writer', 'tt0944947,tt0389557,tt0985699,tt1053424', 'Carice', 'van Houten', None, None, None, None, 1976.0, None),
#  ('nm0997747', 'Gary Pillai', 'actor,producer,miscellaneous', 'tt0944947,tt0893402,tt0183068,tt0485301', 'Gary', 'Pillai', None, None, None, None, 1968.0, None),
#  ('nm2075330', 'Mark Killeen', 'actor', 'tt1877830,tt1462764,tt0944947,tt14792896', 'Mark', 'Killeen', None, None, None, None, None, None),
#  ('nm0064155', 'Ian Beattie', 'actor,director,writer', 'tt0346491,tt0944947,tt2567712,tt16350296', 'Ian', 'Beattie', None, None, None, None, 1965.0, None),
#  ('nm4460936', 'Antonia Christophers', 'actress', 'tt0944947,tt1951140,tt1778108', 'Antonia', 'Christophers', None, None, None, None, None, None),
#  ('nm4595425', 'Boyd Rankin', 'miscellaneous,actor,art_department', 'tt1240982,tt0349683,tt0944947,tt3208026', 'Boyd', 'Rankin', None, None, None, None, 1945.0, 2019.0),
#  ('nm2489799', 'Elisa Lasowski', 'actress,soundtrack', 'tt1172206,tt3830558,tt17220216', 'Elisa', 'Lasowski', None, None, None, None, 1986.0, None),
#  ('nm0815420', 'Mia Soteriou', 'actress,composer,music_department', 'tt0795421,tt0765443,tt0117589,tt0151568', 'Mia', 'Soteriou', None, None, None, None, None, None),
#  ('nm2812026', 'Nathalie Emmanuel', 'actress,producer,archive_footage', 'tt2820852,tt4046784,tt0944947,tt5433138', 'Nathalie', 'Emmanuel', None, None, None, None, 1989.0, None),
#  ('nm2197118', 'Ciaran Bermingham', 'actor,producer', 'tt15323598,tt0944947,tt6095984,tt4714568', 'Ciaran', 'Bermingham', None, None, None, None, None, None),
#  ('nm0634139', 'Reece Noi', 'actor,writer', 'tt7137906,tt0944947,tt2232345,tt0487189', 'Reece', 'Noi', None, None, None, None, 1988.0, None),
#  ('nm5652293', 'Nanna Bryndís Hilmarsdóttir', 'actress,composer,music_department', 'tt0359950,tt0944947,tt2355495,tt12809988', 'Nanna', 'Hilmarsdóttir', 'Bryndís', None, None, None, None, None),
#  ('nm1743706', 'Jon Thor Birgisson', 'composer,music_department,actor', 'tt1389137,tt1646971,tt2386490,tt0892769', 'Jon', 'Birgisson', 'Thor', None, None, None, 1975.0, None),
#  ('nm5652121', 'Ragnar Þórhallsson', 'actor,composer,music_department', 'tt0359950,tt0944947,tt12809988,tt1520211', 'Ragnar', 'Þórhallsson', None, None, None, None, None, None),
#  ('nm1743714', 'Orri P. Dyrason', 'composer,music_department,producer', 'tt0259711,tt0362270,tt1477834,tt1403981', 'Orri', 'Dyrason', 'P.', None, None, None, 1977.0, None),
#  ('nm1743730', 'Georg Holm', 'composer,music_department,actor', 'tt0259711,tt0362270,tt1477834,tt1403981', 'Georg', 'Holm', None, None, None, None, 1976.0, None),
#  ('nm8158202', 'Arnar Rosenkranz Hilmarsson', 'actor,composer,music_department', 'tt0944947,tt1520211,tt0072562,tt3801702', 'Arnar', 'Hilmarsson', 'Rosenkranz', None, None, None, None, None),
#  ('nm8158203', 'Brynjar Leifsson', 'actor,music_department,soundtrack', 'tt0944947,tt1520211,tt19801336,tt10676534', 'Brynjar', 'Leifsson', None, None, None, None, None, None),
#  ('nm1944894', 'Kristján Kristjánsson', 'actor,music_department,composer', 'tt8385148,tt2431438,tt0944947,tt1520211', 'Kristján', 'Kristjánsson', None, None, None, None, 1956.0, None),
#  ('nm4430905', 'Rhodri Hosking', 'actor', 'tt0944947,tt2395417,tt0096555,tt11238716', 'Rhodri', 'Hosking', None, None, None, None, None, None),
#  ('nm3745225', 'Charlotte Hope', 'actress,soundtrack', 'tt3640424,tt1707386,tt2980516,tt5814060', 'Charlotte', 'Hope', None, None, None, None, 1991.0, None),
#  ('nm9132255', 'Harry Grasby', 'actor', 'tt0944947,tt3814634,tt5650650', 'Harry', 'Grasby', None, None, None, None, None, None),
#  ('nm0642751', "Frank O'Sullivan", 'actor', 'tt0119683,tt0117039,tt2357908,tt0944947', 'Frank', "O'Sullivan", None, None, None, None, None, None),
#  ('nm4475182', 'Dennis McKeever', 'actor', 'tt0944947', 'Dennis', 'McKeever', None, None, None, None, None, None),
#  ('nm5792452', 'Michael Stuart', 'actor,assistant_director,sound_department', 'tt2145829,tt1316078,tt7143726,tt2766800', 'Michael', 'Stuart', None, None, None, None, None, None),
#  ('nm2228622', 'Marcus Lamb', 'actor', 'tt6225520,tt7768192,tt26237514,tt31249476', 'Marcus', 'Lamb', None, None, None, None, None, None),
#  ('nm6706699', 'Michael Hooley', 'casting_department,casting_director,actor', 'tt11138512,tt2906216,tt1212428,tt0944947', 'Michael', 'Hooley', None, None, None, None, None, None),
#  ('nm3561455', 'Patrick J Molloy', 'actor', 'tt0944947,tt4577468,tt2460366,tt5436486', 'Patrick', 'Molloy', 'J', None, None, None, None, None),
#  ('nm0371160', 'Michael Hayes', 'actor', 'tt0417791,tt0944947,tt3463106,tt0332658', 'Michael', 'Hayes', None, None, None, None, None, None),
#  ('nm6316115', 'Ruairí Heading', 'actor,writer,director', 'tt23458434,tt0944947,tt3208026,tt15429268', 'Ruairí', 'Heading', None, None, None, None, 1991.0, None),
#  ('nm0283642', 'Tony Flynn', 'actor', 'tt14466018,tt6036728,tt21282348,tt2294189', 'Tony', 'Flynn', None, None, None, None, None, None),
#  ('nm5697839', 'Jed Murray', 'actor', 'tt8233874,tt0944947,tt3480948,tt11311302', 'Jed', 'Murray', None, None, None, None, None, None),
#  ('nm3725055', 'Jessica Henwick', 'actress,writer,director', 'tt18363072,tt11564570,tt15301300,tt2222042', 'Jessica', 'Henwick', None, None, None, None, None, None),
#  ('nm1095720', 'Keisha Castle-Hughes', 'actress,producer,art_director', 'tt0298228,tt0762121,tt0121766,tt0469099', 'Keisha', 'Castle-Hughes', None, None, None, None, 1990.0, None),
#  ('nm0050959', 'Pedro Pascal', 'actor,producer,soundtrack', 'tt3581920,tt8111088,tt0944947,tt4649466', 'Pedro', 'Pascal', None, None, None, None, 1975.0, None),
#  ('nm0424191', 'Margaret John', 'actress,soundtrack,archive_footage', 'tt0425413,tt0944947,tt0207888,tt0076987', 'Margaret', 'John', None, None, None, None, 1926.0, 2011.0),
#  ('nm0610312', 'Gina Moxley', 'actress,writer,director', 'tt0944947,tt0120865,tt0215879,tt0117674', 'Gina', 'Moxley', None, None, None, None, None, None),
#  ('nm0001671', 'Diana Rigg', 'actress,costume_department,costume_designer', 'tt9639470,tt0064757,tt0944947,tt0054518', 'Diana', 'Rigg', None, None, None, None, 1938.0, 2020.0),
#  ('nm5282143', "Brenock O'Connor", 'actor', 'tt0944947,tt4531728,tt6964748,tt27531651', 'Brenock', "O'Connor", None, None, None, None, 2000.0, None),
#  ('nm4831584', 'Will Tudor', 'actor,archive_footage', 'tt0944947,tt4122068,tt4145054,tt3428478', 'Will', 'Tudor', None, None, None, None, 1987.0, None),
#  ('nm0188871', 'Mackenzie Crook', 'actor,writer,director', 'tt0325980,tt4082744,tt0449088,tt0383574', 'Mackenzie', 'Crook', None, None, None, None, 1971.0, None),
#  ('nm4789912', 'Hannah John-Kamen', 'actress,soundtrack', 'tt5095030,tt1677720,tt6920084,tt2488496', 'Hannah', 'John-Kamen', None, None, None, None, 1989.0, None),
#  ('nm1164730', 'Natalia Tena', 'actress,writer,soundtrack', 'tt0373889,tt0276751,tt0417741,tt1201607', 'Natalia', 'Tena', None, None, None, None, 1984.0, None),
#  ('nm1987270', 'Brian Fortune', 'actor,archive_footage', 'tt2521236', 'Brian', 'Fortune', None, None, None, None, None, None),
#  ('nm4422639', 'Rania Zouari', 'actress', 'tt0944947,tt1735200', 'Rania', 'Zouari', None, None, None, None, None, None),
#  ('nm0318821', 'Aidan Gillen', 'actor,writer,producer', 'tt0944947,tt4046784,tt1345836,tt4500922', 'Aidan', 'Gillen', None, None, None, None, 1968.0, None),
#  ('nm4535552', 'Daniel Portman', 'actor', 'tt0944947,tt11846996,tt11725900,tt2085059', 'Daniel', 'Portman', None, None, None, None, 1992.0, None),
#  ('nm3464945', 'Andy Kellegher', 'actor', 'tt0944947,tt4320944,tt4971424,tt2306299', 'Andy', 'Kellegher', None, None, None, None, None, None),
#  ('nm0863130', 'Ramon Tikaram', 'actor,soundtrack,archive_sound', 'tt1617661,tt1686821,tt3763912,tt0116743', 'Ramon', 'Tikaram', None, None, None, None, 1967.0, None),
#  ('nm0360171', 'Ian Hanmore', 'actor,archive_footage', 'tt2906216,tt1687901,tt0318411,tt0944947', 'Ian', 'Hanmore', None, None, None, None, 1953.0, None),
#  ('nm1086981', 'Josef Altin', 'actor,soundtrack,archive_footage', 'tt0765443,tt0944947,tt2527338,tt0962736', 'Josef', 'Altin', None, None, None, None, 1983.0, None),
#  ('nm7047874', 'Staz Nair', 'actor,soundtrack,archive_footage', 'tt14998742,tt0944947,tt23137904,tt1267299', 'Staz', 'Nair', None, None, None, None, 1991.0, None),
#  ('nm1409802', 'Simon Armstrong', 'actor', 'tt1448755,tt10280634,tt0944947,tt1371155', 'Simon', 'Armstrong', None, None, None, None, None, None),
#  ('nm1502469', 'Dar Salim', 'actor,producer,archive_footage', 'tt4873118,tt0944947,tt1270262,tt5431082', 'Dar', 'Salim', None, None, None, None, 1977.0, None),
#  ('nm3671418', 'Laura Pradelska', 'actress', 'tt5484010,tt4230938', 'Laura', 'Pradelska', None, None, None, None, None, None),
#  ('nm0504320', 'Anton Lesser', 'actor,archive_footage', 'tt1298650,tt0944947,tt6108178,tt0482546', 'Anton', 'Lesser', None, None, None, None, 1952.0, None),
#  ('nm1175468', 'Elyes Gabel', 'actor,director,producer', 'tt0816711,tt2937898,tt3514324,tt7460842', 'Elyes', 'Gabel', None, None, None, None, 1983.0, None),
#  ('nm3701064', 'Iwan Rheon', 'actor,producer,soundtrack', 'tt0944947,tt1548850,tt0800325,tt1981140', 'Iwan', 'Rheon', None, None, None, None, 1985.0, None),
#  ('nm0269077', 'James Faulkner', 'actor,producer,archive_footage', 'tt7388562,tt1606375,tt0944947,tt2406566', 'James', 'Faulkner', None, None, None, None, 1948.0, None),
#  ('nm4430828', 'Luke Barnes', 'actor,writer,editor', 'tt0944947,tt3366354,tt5306820,tt4648860', 'Luke', 'Barnes', None, None, None, None, None, None),
#  ('nm1745190', 'George Georgiou', 'actor', 'tt10366206,tt7767422,tt0944947,tt0489974', 'George', 'Georgiou', None, None, None, None, None, None),
#  ('nm4164318', 'Hugo Culverhouse', 'assistant_director,actor,miscellaneous', 'tt0944947,tt5335800,tt6250162,tt4360468', 'Hugo', 'Culverhouse', None, None, None, None, None, None),
#  ('nm4927489', 'Melanie Liburd', 'actress,archive_footage', 'tt4919268,tt6928892,tt5555260,tt4159076', 'Melanie', 'Liburd', None, None, None, None, None, None),
#  ('nm3822462', 'Rila Fukushima', 'actress,soundtrack,archive_footage', 'tt1430132,tt1219827,tt2193021,tt0944947', 'Rila', 'Fukushima', None, None, None, None, None, None),
#  ('nm2167445', 'Gethin Anthony', 'actor,director,writer', 'tt5618256,tt3768572,tt2459156,tt0944947', 'Gethin', 'Anthony', None, None, None, None, None, None),
#  ('nm3280686', 'Art Parkinson', 'actor,archive_footage', 'tt4302938,tt2126355,tt0944947,tt8425404', 'Art', 'Parkinson', None, None, None, None, 2001.0, None),
#  ('nm0534635', 'Richard Madden', 'actor,producer,soundtrack', 'tt0944947,tt2368619,tt2066051,tt1661199', 'Richard', 'Madden', None, None, None, None, 1986.0, None),
#  ('nm0004692', 'Mark Addy', 'actor,music_department,soundtrack', 'tt0119164,tt0183790,tt0944947,tt0955308', 'Mark', 'Addy', None, None, None, None, 1964.0, None),
#  ('nm0570570', 'Tim McInnerny', 'actor,archive_footage,archive_sound', 'tt0125439,tt0944947,tt0464196,tt4614612', 'Tim', 'McInnerny', None, None, None, None, 1956.0, None),
#  ('nm2996220', 'Lino Facioli', 'actor', 'tt1226229,tt2343380,tt0944947,tt1441940', 'Lino', 'Facioli', None, None, None, None, 2000.0, None),
#  ('nm0231871', 'Ron Donachie', 'actor,soundtrack,archive_footage', 'tt0120338,tt1029235,tt0944947,tt1297919', 'Ron', 'Donachie', None, None, None, None, 1956.0, None),
#  ('nm0568385', 'Michael McElhatton', 'actor,writer,archive_footage', 'tt0944947,tt5057054,tt7366338,tt13323596', 'Michael', 'McElhatton', None, None, None, None, 1963.0, None),
#  ('nm0065874', 'Andy Beckwith', 'actor,archive_footage', 'tt1355631,tt0944947,tt5691024,tt0208092', 'Andy', 'Beckwith', None, None, None, None, None, None),
#  ('nm2657974', 'Esmé Bianco', 'actress', 'tt0944947,tt4254242,tt2758770,tt4016454', 'Esmé', 'Bianco', None, None, None, None, 1982.0, None),
#  ('nm5093301', 'Alexandra Dowling', 'actress', 'tt1742179,tt2733252,tt0944947,tt12374656', 'Alexandra', 'Dowling', None, None, None, None, 1990.0, None),
#  ('nm1414435', 'Robert Sterne', 'casting_director,casting_department,actor', 'tt0944947,tt4786824,tt1478964,tt9603212', 'Robert', 'Sterne', None, None, None, None, None, None),
#  ('nm0565472', 'Bryan McCaugherty', 'actor', 'tt0944947,tt1186340,tt0218182', 'Bryan', 'McCaugherty', None, None, None, None, None, None),
#  ('nm1748634', 'Lucian Msamati', 'actor,producer', 'tt13640696,tt0963178,tt1356380,tt5563334', 'Lucian', 'Msamati', None, None, None, None, 1976.0, None),
#  ('nm4263213', 'John Bradley', 'actor,soundtrack,archive_footage', 'tt0944947,tt5834426,tt10223460,tt5451690', 'John', 'Bradley', None, None, None, None, 1988.0, None),
#  ('nm0564920', 'Rory McCann', 'actor,archive_footage', 'tt0944947,tt7975244,tt0425112,tt3205376', 'Rory', 'McCann', None, None, None, None, 1969.0, None),
#  ('nm3849842', 'Sophie Turner', 'actress,archive_footage', 'tt0944947,tt6565702,tt3385516,tt1731701', 'Sophie', 'Turner', None, None, None, None, 1996.0, None),
#  ('nm1378629', 'Maggie Hayes', 'actress', 'tt0944947,tt1248971,tt1205458,tt1205456', 'Maggie', 'Hayes', None, None, None, None, None, None),
#  ('nm0114742', 'Susan Brown', 'actress,soundtrack,archive_footage', 'tt0944947,tt1007029,tt0485301,tt2404181', 'Susan', 'Brown', None, None, None, None, 1946.0, None),
#  ('nm1103771', 'Mary Jordan', 'actress', 'tt4652844,tt0061260,tt1948974,tt0129723', 'Mary', 'Jordan', None, None, None, None, 1913.0, 1973.0),
#  ('nm1821446', 'Hannah Waddingham', 'actress,producer,soundtrack', 'tt1684562,tt10986410,tt0455538,tt1707386', 'Hannah', 'Waddingham', None, None, None, None, 1974.0, None),
#  ('nm0352901', 'Kenneth Hadley', 'actor', 'tt0462335,tt0151568,tt2023690,tt1255919', 'Kenneth', 'Hadley', None, None, None, None, None, None),
#  ('nm0126298', 'Terry Byrne', 'actor', 'tt0944947,tt0264333,tt0312549,tt9742392', 'Terry', 'Byrne', None, None, None, None, None, 2023.0),
#  ('nm4757478', 'Dez McMahon', 'actor', 'tt2306299,tt0944947,tt3463106,tt0085020', 'Dez', 'McMahon', None, None, None, None, None, None),
#  ('nm1402546', 'Sibel Kekilli', 'actress,archive_footage', 'tt0347048,tt1288376,tt0944947,tt0806910', 'Sibel', 'Kekilli', None, None, None, None, 1980.0, None),
#  ('nm0428765', 'Mark Lewis Jones', 'actor,soundtrack', 'tt7661390,tt7366338,tt2527336,tt4786824', 'Mark', 'Jones', 'Lewis', None, None, None, 1964.0, None),
#  ('nm5081192', 'Kerry Ingram', 'actress,soundtrack,archive_footage', 'tt1707386,tt0944947,tt6928052,tt0241383', 'Kerry', 'Ingram', None, None, None, None, 1999.0, None),
#  ('nm0432838', 'Slavko Juraga', 'actor', 'tt0119874,tt0944947,tt2034403,tt2427220', 'Slavko', 'Juraga', None, None, None, None, 1959.0, None),
#  ('nm2746504', 'Dean Jagger', 'actor,writer,producer', 'tt0944947,tt5743796,tt7949218,tt23037488', 'Dean', 'Jagger', None, None, None, None, 1978.0, None),
#  ('nm0087432', 'Nicholas Blane', 'actor,archive_footage', 'tt2906216,tt0443543,tt0373889,tt0944947', 'Nicholas', 'Blane', None, None, None, None, None, None),
#  ('nm0226820', 'Stephen Dillane', 'actor,soundtrack,archive_footage', 'tt0274558,tt0944947,tt4555426,tt0266987', 'Stephen', 'Dillane', None, None, None, None, 1957.0, None),
#  ('nm5792452', 'Michael Stuart', 'actor,assistant_director,sound_department', 'tt2145829,tt1316078,tt7143726,tt2766800', 'Michael', 'Stuart', None, None, None, None, None, None),
#  ('nm4335246', 'Faolan Morgan', 'actor,miscellaneous', 'tt0462335,tt0944947,tt3546370,tt14466018', 'Faolan', 'Morgan', None, None, None, None, None, None),
#  ('nm4492916', 'Rick Burn', 'actor', 'tt2306299,tt0944947,tt8553578,tt2628232', 'Rick', 'Burn', None, None, None, None, None, None),
#  ('nm1423916', 'David Sheehan', 'actor', 'tt0944947,tt0758790,tt0170930,tt0383087', 'David', 'Sheehan', None, None, None, None, None, None),
#  ('nm5981376', 'Paul Monahan', 'actor', 'tt0829150,tt2606788,tt11583012', 'Paul', 'Monahan', None, None, None, None, None, None),
#  ('nm1652341', 'Jamie Michie', 'actor', 'tt1758810,tt1390411,tt6679794,tt0944947', 'Jamie', 'Michie', None, None, None, None, 1977.0, None),
#  ('nm1794801', 'Colin Carnegie', 'actor', 'tt0462335,tt2906216,tt1212428,tt0944947', 'Colin', 'Carnegie', None, None, None, None, None, None),
#  ('nm1651043', 'Stephen Don', 'actor,writer,producer', 'tt2823568,tt6039842,tt0944947,tt7305632', 'Stephen', 'Don', None, None, None, None, None, None),
#  ('nm0464305', 'Yuri Kolokolnikov', 'actor,producer,archive_footage', 'tt1846589,tt6723592,tt8106534,tt1959563', 'Yuri', 'Kolokolnikov', None, None, None, None, 1980.0, None),
#  ('nm1115654', 'Miltos Yerolemou', 'actor', 'tt2488496,tt8385148,tt3402236,tt0810819', 'Miltos', 'Yerolemou', None, None, None, None, None, None),
#  ('nm2772105', 'Oona Chaplin', 'actress,producer,soundtrack', 'tt2726560,tt0944947,tt0830515,tt5637536', 'Oona', 'Chaplin', None, None, None, None, 1986.0, None),
#  ('nm5039410', 'Rebecca Benson', 'actress', 'tt8128344,tt5705956,tt0944947,tt2884018', 'Rebecca', 'Benson', None, None, None, None, None, None),
#  ('nm1146807', 'Gary Oliver', 'actor,archive_footage', 'tt0944947,tt2245988,tt0959601,tt21366490', 'Gary', 'Oliver', None, None, None, None, None, None),
#  ('nm1212069', 'Bart the Bear', 'actor', 'tt0364751,tt1389137,tt0758758,tt1694021', 'Bart the Bear', None, None, None, None, None, 2000.0, 2021.0),
#  ('nm1677757', 'Anthony Morris', 'actor', 'tt1893256,tt26736843,tt9243804,tt0944947', 'Anthony', 'Morris', None, None, None, None, None, None),
#  ('nm3849670', 'Faye Marsay', 'actress', 'tt0944947,tt3169706,tt9253284,tt4555426', 'Faye', 'Marsay', None, None, None, None, 1986.0, None),
#  ('nm1395532', 'Joseph Gatt', 'actor,miscellaneous,cinematographer', 'tt3861390,tt0944947,tt1408101,tt2017109', 'Joseph', 'Gatt', None, None, None, None, None, None),
#  ('nm0654295', 'Alfie Allen', 'actor,soundtrack,archive_footage', 'tt2911666,tt0944947,tt3829266,tt0467200', 'Alfie', 'Allen', None, None, None, None, 1986.0, None),
#  ('nm0534062', 'Oengus MacNamara', 'actor', 'tt5932728,tt0944947,tt5932548,tt5180504', 'Oengus', 'MacNamara', None, None, None, None, None, None),
#  ('nm0443373', 'Paul Kaye', 'actor,writer,composer', 'tt9698480,tt0944947,tt6835252', 'Paul', 'Kaye', None, None, None, None, 1965.0, None),
#  ('nm4385245', 'Tobias Winter', 'actor', 'tt1240982,tt0944947,tt2294189,tt2653354', 'Tobias', 'Winter', None, None, None, None, None, None),
#  ('nm0928408', 'Andrew Wilde', 'actor', 'tt0087803,tt0086993,tt0944947,tt0098765', 'Andrew', 'Wilde', None, None, None, None, None, None),
#  ('nm3727276', "Will O'Connell", 'actor,miscellaneous', 'tt6813264,tt6853528,tt0944947,tt3096344', 'Will', "O'Connell", None, None, None, None, None, None),
#  ('nm4475303', 'Phil Dixon', 'actor', 'tt0944947', 'Phil', 'Dixon', None, None, None, None, None, None),
#  ('nm1970465', 'Kristofer Hivju', 'actor,writer,producer', 'tt2121382,tt0944947,tt14209916,tt0905372', 'Kristofer', 'Hivju', None, None, None, None, 1978.0, None),
#  ('nm4514519', 'Toby Sebastian', 'actor,writer,soundtrack', 'tt1928340,tt0944947,tt5070062,tt3068894', 'Toby', 'Sebastian', None, None, None, None, 1992.0, None),
#  ('nm0309693', 'Mark Gatiss', 'actor,writer,producer', 'tt0184135,tt1475582,tt0371724,tt4575576', 'Mark', 'Gatiss', None, None, None, None, 1966.0, None),
#  ('nm3065809', 'Rosabell Laurenti Sellers', 'actress', 'tt2370096,tt2751576,tt0896872,tt2882850', 'Rosabell', 'Sellers', 'Laurenti', None, None, None, 1996.0, None),
#  ('nm0227759', 'Peter Dinklage', 'actor,producer,stunts', 'tt0944947,tt0340377,tt1877832,tt5027774', 'Peter', 'Dinklage', None, None, None, None, 1969.0, None),
#  ('nm0001097', 'Charles Dance', 'actor,producer,director', 'tt0280707,tt2084970,tt0944947,tt0103644', 'Charles', 'Dance', None, None, None, None, 1946.0, None),
#  ('nm5159884', 'Meena Rayann', 'actress', 'tt4761112,tt1298644,tt0944947,tt2988884', 'Meena', 'Rayann', None, None, None, None, None, None),
#  ('nm1788152', 'Brendan McCormack', 'actor', 'tt1235796,tt0944947,tt0800286,tt0808096', 'Brendan', 'McCormack', None, None, None, None, None, None),
#  ('nm1378721', 'Graham Charles', 'actor', 'tt3231054,tt0944947,tt7388562,tt1091989', 'Graham', 'Charles', None, None, None, None, None, None),
#  ('nm0516003', 'Harry Lloyd', 'actor,writer,producer', 'tt2980516,tt1007029,tt4190530,tt1229822', 'Harry', 'Lloyd', None, None, None, None, 1983.0, None),
#  ('nm3531913', 'Elizabeth Webster', 'actress,producer', 'tt0944947,tt2414766,tt1362058,tt2939156', 'Elizabeth', 'Webster', None, None, None, None, None, None),
#  ('nm0103195', 'David Bradley', 'actor,location_management,soundtrack', 'tt1213663,tt0425112,tt1201607,tt0417741', 'David', 'Bradley', None, None, None, None, 1942.0, None),
#  ('nm5390029', 'Lottie Steer', 'actress', 'tt1109624,tt1707386,tt1014763,tt0944947', 'Lottie', 'Steer', None, None, None, None, None, None),
#  ('nm3209935', 'Rob Ostlere', 'actor', 'tt0944947,tt10846464,tt6654210,tt0184122', 'Rob', 'Ostlere', None, None, None, None, 1984.0, None),
#  ('nm1460176', 'Sigur Rós', 'composer,music_department,actor', 'tt0259711,tt1477834,tt0362270,tt1403981', 'Sigur', 'Rós', None, None, None, None, None, None),
#  ('nm1613839', 'Ian Whyte', 'actor,miscellaneous,stunts', 'tt9253284,tt0944947,tt1446714,tt11138512', 'Ian', 'Whyte', None, None, None, None, 1971.0, None),
#  ('nm1368643', 'Ross Mullan', 'actor,miscellaneous', 'tt0800320,tt3416532,tt10954600,tt0944947', 'Ross', 'Mullan', None, None, None, None, 1967.0, None),
#  ('nm0516385', 'Tim Loane', 'writer,actor,miscellaneous', 'tt0140934,tt0944947,tt0280330,tt27495613', 'Tim', 'Loane', None, None, None, None, None, None),
#  ('nm1872855', 'Spencer Wilding', 'actor,stunts,producer', 'tt3748528,tt1976009,tt1043726,tt0486655', 'Spencer', 'Wilding', None, None, None, None, 1972.0, None),
#  ('nm4422708', 'Claire Wright', 'actress,archive_footage', 'tt0944947,tt2653352', 'Claire', 'Wright', None, None, None, None, None, None),
#  ('nm0916037', 'Bronson Webb', 'actor,soundtrack', 'tt1032755,tt0320661,tt0783233,tt0304141', 'Bronson', 'Webb', None, None, None, None, 1983.0, None),
#  ('nm5624523', 'Timothy Gibbons', 'costume_department,actor,costume_designer', 'tt0829150,tt9051908,tt0944947,tt30851137', 'Timothy', 'Gibbons', None, None, None, None, None, None),
#  ('nm4416560', 'Ryan McKenna', 'actor', 'tt2567712,tt0944947,tt1205456,tt0780217', 'Ryan', 'McKenna', None, None, None, None, None, None),
#  ('nm0523047', 'Simon Lowe', 'actor', 'tt1351685,tt2527336,tt1266029,tt0944947', 'Simon', 'Lowe', None, None, None, None, None, None),
#  ('nm0214343', 'Donagh Deeney', 'actor', 'tt0944947,tt0307919,tt2070064,tt1880641', 'Donagh', 'Deeney', None, None, None, None, None, None),
#  ('nm1613839', 'Ian Whyte', 'actor,miscellaneous,stunts', 'tt9253284,tt0944947,tt1446714,tt11138512', 'Ian', 'Whyte', None, None, None, None, 1971.0, None),
#  ('nm4744043', 'Sam Coleman', 'actor,camera_department', 'tt0944947,tt2620590,tt4669296,tt5995864', 'Sam', 'Coleman', None, None, None, None, 1996.0, None),
#  ('nm1996829', 'Nonso Anozie', 'actor,producer,archive_footage', 'tt1661199,tt0816462,tt1045670,tt0462396', 'Nonso', 'Anozie', None, None, None, None, 1978.0, None),
#  ('nm2247629', 'Gemma Whelan', 'actress,archive_footage', 'tt0944947,tt0780653,tt9214832,tt1320261', 'Gemma', 'Whelan', None, None, None, None, 1981.0, None),
#  ('nm0162281', 'Enzo Cilenti', 'actor,producer', 'tt4158096,tt1226774,tt2015381,tt0435705', 'Enzo', 'Cilenti', None, None, None, None, 1974.0, None),
#  ('nm3310211', 'Rose Leslie', 'actress,archive_footage', 'tt3177316,tt0944947,tt1618442,tt4520364', 'Rose', 'Leslie', None, None, None, None, 1987.0, None),
#  ('nm0889338', 'Rupert Vansittart', 'actor,miscellaneous,archive_footage', 'tt0112573,tt0107943,tt0944947,tt0109831', 'Rupert', 'Vansittart', None, None, None, None, 1958.0, None),
#  ('nm0535837', 'Francis Magee', 'actor,archive_footage', 'tt0375912,tt12361974,tt3748528,tt0974015', 'Francis', 'Magee', None, None, None, None, 1969.0, None),
#  ('nm5502295', 'Matteo Elezi', 'actor,visual_effects,miscellaneous', 'tt0944947,tt5595168,tt1340758', 'Matteo', 'Elezi', None, None, None, None, None, None),
#  ('nm5309709', 'Nell Williams', 'actress,producer', 'tt8266310,tt5563334,tt0944947,tt3154822', 'Nell', 'Williams', None, None, None, None, None, None),
#  ('nm8108764', 'Cordelia Hill', 'actress', 'tt0944947', 'Cordelia', 'Hill', None, None, None, None, None, None),
#  ('nm1519719', 'Annette Tierney', 'actress', 'tt0944947,tt3777860,tt0810725,tt0490539', 'Annette', 'Tierney', None, None, None, None, None, None),
#  ('nm7075019', 'Robert Aramayo', 'actor,producer,archive_footage', 'tt5867314,tt10065694,tt6856242,tt4550098', 'Robert', 'Aramayo', None, None, None, None, 1992.0, None),
#  ('nm7509185', 'Sebastian Croft', 'actor,music_department,soundtrack', 'tt10638036,tt16156616,tt7715070,tt9561862', 'Sebastian', 'Croft', None, None, None, None, 2001.0, None),
#  ('nm7509186', 'Fergus Leathem', 'actor', 'tt0944947,tt6282542', 'Fergus', 'Leathem', None, None, None, None, None, None),
#  ('nm0503319', 'Gerald Lepkowski', 'actor,director,writer', 'tt4686844,tt0324992,tt0944947,tt5688694', 'Gerald', 'Lepkowski', None, None, None, None, 1966.0, None)]

# %% [markdown]
# ## Load the Character Information into MongoDB

# %%
character_info_file = "../data/GoT/character_relationship_scenes.json"
with open(character_info_file) as in_file:
    character_info = json.load(in_file)

# %%
character_info[0:2]
# Out:
# [{'_id': {'$oid': '65aa4b003c830ea6acd774d4'},
#   'seasonNum': 1,
#   'episodeNum': 1,
#   'sceneNum': 9,
#   'characterName': 'Waymar Royce',
#   'killedBy': 'White Walker'},
#  {'_id': {'$oid': '65aa4b003c830ea6acd774d4'},
#   'seasonNum': 1,
#   'episodeNum': 1,
#   'sceneNum': 12,
#   'characterName': 'Gared',
#   'killedBy': 'White Walker'}]

# %%
# Get ride of the "_id" because that is old information.
#
for c in character_info:
    del c["_id"]

# %%
character_info[0:2]
# Out:
# [{'seasonNum': 1,
#   'episodeNum': 1,
#   'sceneNum': 9,
#   'characterName': 'Waymar Royce',
#   'killedBy': 'White Walker'},
#  {'seasonNum': 1,
#   'episodeNum': 1,
#   'sceneNum': 12,
#   'characterName': 'Gared',
#   'killedBy': 'White Walker'}]

# %%
# Insert the documents into mongodb.
database = client["S25_GoT"]
collection = database["characters_scenes_relationships"]

# %%
result = collection.insert_many(character_info)

# %%
result.inserted_ids
# Out:
# [ObjectId('67f0f764eb5a9851a3008dcf'),
#  ObjectId('67f0f764eb5a9851a3008dd0'),
#  ObjectId('67f0f764eb5a9851a3008dd1'),
#  ObjectId('67f0f764eb5a9851a3008dd2'),
#  ObjectId('67f0f764eb5a9851a3008dd3'),
#  ObjectId('67f0f764eb5a9851a3008dd4'),
#  ObjectId('67f0f764eb5a9851a3008dd5'),
#  ObjectId('67f0f764eb5a9851a3008dd6'),
#  ObjectId('67f0f764eb5a9851a3008dd7'),
#  ObjectId('67f0f764eb5a9851a3008dd8'),
#  ObjectId('67f0f764eb5a9851a3008dd9'),
#  ObjectId('67f0f764eb5a9851a3008dda'),
#  ObjectId('67f0f764eb5a9851a3008ddb'),
#  ObjectId('67f0f764eb5a9851a3008ddc'),
#  ObjectId('67f0f764eb5a9851a3008ddd'),
#  ObjectId('67f0f764eb5a9851a3008dde'),
#  ObjectId('67f0f764eb5a9851a3008ddf'),
#  ObjectId('67f0f764eb5a9851a3008de0'),
#  ObjectId('67f0f764eb5a9851a3008de1'),
#  ObjectId('67f0f764eb5a9851a3008de2'),
#  ObjectId('67f0f764eb5a9851a3008de3'),
#  ObjectId('67f0f764eb5a9851a3008de4'),
#  ObjectId('67f0f764eb5a9851a3008de5'),
#  ObjectId('67f0f764eb5a9851a3008de6'),
#  ObjectId('67f0f764eb5a9851a3008de7'),
#  ObjectId('67f0f764eb5a9851a3008de8'),
#  ObjectId('67f0f764eb5a9851a3008de9'),
#  ObjectId('67f0f764eb5a9851a3008dea'),
#  ObjectId('67f0f764eb5a9851a3008deb'),
#  ObjectId('67f0f764eb5a9851a3008dec'),
#  ObjectId('67f0f764eb5a9851a3008ded'),
#  ObjectId('67f0f764eb5a9851a3008dee'),
#  ObjectId('67f0f764eb5a9851a3008def'),
#  ObjectId('67f0f764eb5a9851a3008df0'),
#  ObjectId('67f0f764eb5a9851a3008df1'),
#  ObjectId('67f0f764eb5a9851a3008df2'),
#  ObjectId('67f0f764eb5a9851a3008df3'),
#  ObjectId('67f0f764eb5a9851a3008df4'),
#  ObjectId('67f0f764eb5a9851a3008df5'),
#  ObjectId('67f0f764eb5a9851a3008df6'),
#  ObjectId('67f0f764eb5a9851a3008df7'),
#  ObjectId('67f0f764eb5a9851a3008df8'),
#  ObjectId('67f0f764eb5a9851a3008df9'),
#  ObjectId('67f0f764eb5a9851a3008dfa'),
#  ObjectId('67f0f764eb5a9851a3008dfb'),
#  ObjectId('67f0f764eb5a9851a3008dfc'),
#  ObjectId('67f0f764eb5a9851a3008dfd'),
#  ObjectId('67f0f764eb5a9851a3008dfe'),
#  ObjectId('67f0f764eb5a9851a3008dff'),
#  ObjectId('67f0f764eb5a9851a3008e00'),
#  ObjectId('67f0f764eb5a9851a3008e01'),
#  ObjectId('67f0f764eb5a9851a3008e02'),
#  ObjectId('67f0f764eb5a9851a3008e03'),
#  ObjectId('67f0f764eb5a9851a3008e04'),
#  ObjectId('67f0f764eb5a9851a3008e05'),
#  ObjectId('67f0f764eb5a9851a3008e06'),
#  ObjectId('67f0f764eb5a9851a3008e07'),
#  ObjectId('67f0f764eb5a9851a3008e08'),
#  ObjectId('67f0f764eb5a9851a3008e09'),
#  ObjectId('67f0f764eb5a9851a3008e0a'),
#  ObjectId('67f0f764eb5a9851a3008e0b'),
#  ObjectId('67f0f764eb5a9851a3008e0c'),
#  ObjectId('67f0f764eb5a9851a3008e0d'),
#  ObjectId('67f0f764eb5a9851a3008e0e'),
#  ObjectId('67f0f764eb5a9851a3008e0f'),
#  ObjectId('67f0f764eb5a9851a3008e10'),
#  ObjectId('67f0f764eb5a9851a3008e11'),
#  ObjectId('67f0f764eb5a9851a3008e12'),
#  ObjectId('67f0f764eb5a9851a3008e13'),
#  ObjectId('67f0f764eb5a9851a3008e14'),
#  ObjectId('67f0f764eb5a9851a3008e15'),
#  ObjectId('67f0f764eb5a9851a3008e16'),
#  ObjectId('67f0f764eb5a9851a3008e17'),
#  ObjectId('67f0f764eb5a9851a3008e18'),
#  ObjectId('67f0f764eb5a9851a3008e19'),
#  ObjectId('67f0f764eb5a9851a3008e1a'),
#  ObjectId('67f0f764eb5a9851a3008e1b'),
#  ObjectId('67f0f764eb5a9851a3008e1c'),
#  ObjectId('67f0f764eb5a9851a3008e1d'),
#  ObjectId('67f0f764eb5a9851a3008e1e'),
#  ObjectId('67f0f764eb5a9851a3008e1f'),
#  ObjectId('67f0f764eb5a9851a3008e20'),
#  ObjectId('67f0f764eb5a9851a3008e21'),
#  ObjectId('67f0f764eb5a9851a3008e22'),
#  ObjectId('67f0f764eb5a9851a3008e23'),
#  ObjectId('67f0f764eb5a9851a3008e24'),
#  ObjectId('67f0f764eb5a9851a3008e25'),
#  ObjectId('67f0f764eb5a9851a3008e26'),
#  ObjectId('67f0f764eb5a9851a3008e27'),
#  ObjectId('67f0f764eb5a9851a3008e28'),
#  ObjectId('67f0f764eb5a9851a3008e29'),
#  ObjectId('67f0f764eb5a9851a3008e2a'),
#  ObjectId('67f0f764eb5a9851a3008e2b'),
#  ObjectId('67f0f764eb5a9851a3008e2c'),
#  ObjectId('67f0f764eb5a9851a3008e2d'),
#  ObjectId('67f0f764eb5a9851a3008e2e'),
#  ObjectId('67f0f764eb5a9851a3008e2f'),
#  ObjectId('67f0f764eb5a9851a3008e30'),
#  ObjectId('67f0f764eb5a9851a3008e31'),
#  ObjectId('67f0f764eb5a9851a3008e32'),
#  ObjectId('67f0f764eb5a9851a3008e33'),
#  ObjectId('67f0f764eb5a9851a3008e34'),
#  ObjectId('67f0f764eb5a9851a3008e35'),
#  ObjectId('67f0f764eb5a9851a3008e36'),
#  ObjectId('67f0f764eb5a9851a3008e37'),
#  ObjectId('67f0f764eb5a9851a3008e38'),
#  ObjectId('67f0f764eb5a9851a3008e39'),
#  ObjectId('67f0f764eb5a9851a3008e3a'),
#  ObjectId('67f0f764eb5a9851a3008e3b'),
#  ObjectId('67f0f764eb5a9851a3008e3c'),
#  ObjectId('67f0f764eb5a9851a3008e3d'),
#  ObjectId('67f0f764eb5a9851a3008e3e'),
#  ObjectId('67f0f764eb5a9851a3008e3f'),
#  ObjectId('67f0f764eb5a9851a3008e40'),
#  ObjectId('67f0f764eb5a9851a3008e41'),
#  ObjectId('67f0f764eb5a9851a3008e42'),
#  ObjectId('67f0f764eb5a9851a3008e43'),
#  ObjectId('67f0f764eb5a9851a3008e44'),
#  ObjectId('67f0f764eb5a9851a3008e45'),
#  ObjectId('67f0f764eb5a9851a3008e46'),
#  ObjectId('67f0f764eb5a9851a3008e47'),
#  ObjectId('67f0f764eb5a9851a3008e48'),
#  ObjectId('67f0f764eb5a9851a3008e49'),
#  ObjectId('67f0f764eb5a9851a3008e4a'),
#  ObjectId('67f0f764eb5a9851a3008e4b'),
#  ObjectId('67f0f764eb5a9851a3008e4c'),
#  ObjectId('67f0f764eb5a9851a3008e4d'),
#  ObjectId('67f0f764eb5a9851a3008e4e'),
#  ObjectId('67f0f764eb5a9851a3008e4f'),
#  ObjectId('67f0f764eb5a9851a3008e50'),
#  ObjectId('67f0f764eb5a9851a3008e51'),
#  ObjectId('67f0f764eb5a9851a3008e52'),
#  ObjectId('67f0f764eb5a9851a3008e53'),
#  ObjectId('67f0f764eb5a9851a3008e54'),
#  ObjectId('67f0f764eb5a9851a3008e55'),
#  ObjectId('67f0f764eb5a9851a3008e56'),
#  ObjectId('67f0f764eb5a9851a3008e57'),
#  ObjectId('67f0f764eb5a9851a3008e58'),
#  ObjectId('67f0f764eb5a9851a3008e59'),
#  ObjectId('67f0f764eb5a9851a3008e5a'),
#  ObjectId('67f0f764eb5a9851a3008e5b'),
#  ObjectId('67f0f764eb5a9851a3008e5c'),
#  ObjectId('67f0f764eb5a9851a3008e5d'),
#  ObjectId('67f0f764eb5a9851a3008e5e'),
#  ObjectId('67f0f764eb5a9851a3008e5f'),
#  ObjectId('67f0f764eb5a9851a3008e60'),
#  ObjectId('67f0f764eb5a9851a3008e61'),
#  ObjectId('67f0f764eb5a9851a3008e62'),
#  ObjectId('67f0f764eb5a9851a3008e63'),
#  ObjectId('67f0f764eb5a9851a3008e64'),
#  ObjectId('67f0f764eb5a9851a3008e65'),
#  ObjectId('67f0f764eb5a9851a3008e66'),
#  ObjectId('67f0f764eb5a9851a3008e67'),
#  ObjectId('67f0f764eb5a9851a3008e68'),
#  ObjectId('67f0f764eb5a9851a3008e69'),
#  ObjectId('67f0f764eb5a9851a3008e6a'),
#  ObjectId('67f0f764eb5a9851a3008e6b'),
#  ObjectId('67f0f764eb5a9851a3008e6c'),
#  ObjectId('67f0f764eb5a9851a3008e6d'),
#  ObjectId('67f0f764eb5a9851a3008e6e'),
#  ObjectId('67f0f764eb5a9851a3008e6f'),
#  ObjectId('67f0f764eb5a9851a3008e70'),
#  ObjectId('67f0f764eb5a9851a3008e71'),
#  ObjectId('67f0f764eb5a9851a3008e72'),
#  ObjectId('67f0f764eb5a9851a3008e73'),
#  ObjectId('67f0f764eb5a9851a3008e74'),
#  ObjectId('67f0f764eb5a9851a3008e75'),
#  ObjectId('67f0f764eb5a9851a3008e76'),
#  ObjectId('67f0f764eb5a9851a3008e77'),
#  ObjectId('67f0f764eb5a9851a3008e78'),
#  ObjectId('67f0f764eb5a9851a3008e79'),
#  ObjectId('67f0f764eb5a9851a3008e7a'),
#  ObjectId('67f0f764eb5a9851a3008e7b'),
#  ObjectId('67f0f764eb5a9851a3008e7c'),
#  ObjectId('67f0f764eb5a9851a3008e7d'),
#  ObjectId('67f0f764eb5a9851a3008e7e'),
#  ObjectId('67f0f764eb5a9851a3008e7f'),
#  ObjectId('67f0f764eb5a9851a3008e80'),
#  ObjectId('67f0f764eb5a9851a3008e81'),
#  ObjectId('67f0f764eb5a9851a3008e82'),
#  ObjectId('67f0f764eb5a9851a3008e83'),
#  ObjectId('67f0f764eb5a9851a3008e84'),
#  ObjectId('67f0f764eb5a9851a3008e85'),
#  ObjectId('67f0f764eb5a9851a3008e86'),
#  ObjectId('67f0f764eb5a9851a3008e87'),
#  ObjectId('67f0f764eb5a9851a3008e88'),
#  ObjectId('67f0f764eb5a9851a3008e89'),
#  ObjectId('67f0f764eb5a9851a3008e8a'),
#  ObjectId('67f0f764eb5a9851a3008e8b'),
#  ObjectId('67f0f764eb5a9851a3008e8c'),
#  ObjectId('67f0f764eb5a9851a3008e8d'),
#  ObjectId('67f0f764eb5a9851a3008e8e'),
#  ObjectId('67f0f764eb5a9851a3008e8f'),
#  ObjectId('67f0f764eb5a9851a3008e90'),
#  ObjectId('67f0f764eb5a9851a3008e91'),
#  ObjectId('67f0f764eb5a9851a3008e92'),
#  ObjectId('67f0f764eb5a9851a3008e93'),
#  ObjectId('67f0f764eb5a9851a3008e94'),
#  ObjectId('67f0f764eb5a9851a3008e95'),
#  ObjectId('67f0f764eb5a9851a3008e96'),
#  ObjectId('67f0f764eb5a9851a3008e97'),
#  ObjectId('67f0f764eb5a9851a3008e98'),
#  ObjectId('67f0f764eb5a9851a3008e99'),
#  ObjectId('67f0f764eb5a9851a3008e9a'),
#  ObjectId('67f0f764eb5a9851a3008e9b'),
#  ObjectId('67f0f764eb5a9851a3008e9c'),
#  ObjectId('67f0f764eb5a9851a3008e9d'),
#  ObjectId('67f0f764eb5a9851a3008e9e'),
#  ObjectId('67f0f764eb5a9851a3008e9f'),
#  ObjectId('67f0f764eb5a9851a3008ea0'),
#  ObjectId('67f0f764eb5a9851a3008ea1'),
#  ObjectId('67f0f764eb5a9851a3008ea2'),
#  ObjectId('67f0f764eb5a9851a3008ea3'),
#  ObjectId('67f0f764eb5a9851a3008ea4'),
#  ObjectId('67f0f764eb5a9851a3008ea5'),
#  ObjectId('67f0f764eb5a9851a3008ea6'),
#  ObjectId('67f0f764eb5a9851a3008ea7'),
#  ObjectId('67f0f764eb5a9851a3008ea8'),
#  ObjectId('67f0f764eb5a9851a3008ea9'),
#  ObjectId('67f0f764eb5a9851a3008eaa'),
#  ObjectId('67f0f764eb5a9851a3008eab'),
#  ObjectId('67f0f764eb5a9851a3008eac'),
#  ObjectId('67f0f764eb5a9851a3008ead'),
#  ObjectId('67f0f764eb5a9851a3008eae'),
#  ObjectId('67f0f764eb5a9851a3008eaf'),
#  ObjectId('67f0f764eb5a9851a3008eb0'),
#  ObjectId('67f0f764eb5a9851a3008eb1'),
#  ObjectId('67f0f764eb5a9851a3008eb2'),
#  ObjectId('67f0f764eb5a9851a3008eb3'),
#  ObjectId('67f0f764eb5a9851a3008eb4'),
#  ObjectId('67f0f764eb5a9851a3008eb5'),
#  ObjectId('67f0f764eb5a9851a3008eb6'),
#  ObjectId('67f0f764eb5a9851a3008eb7'),
#  ObjectId('67f0f764eb5a9851a3008eb8'),
#  ObjectId('67f0f764eb5a9851a3008eb9'),
#  ObjectId('67f0f764eb5a9851a3008eba'),
#  ObjectId('67f0f764eb5a9851a3008ebb'),
#  ObjectId('67f0f764eb5a9851a3008ebc'),
#  ObjectId('67f0f764eb5a9851a3008ebd'),
#  ObjectId('67f0f764eb5a9851a3008ebe'),
#  ObjectId('67f0f764eb5a9851a3008ebf'),
#  ObjectId('67f0f764eb5a9851a3008ec0'),
#  ObjectId('67f0f764eb5a9851a3008ec1'),
#  ObjectId('67f0f764eb5a9851a3008ec2')]

# %%
# Do the same for characters in general.
#
character_info_file = "../data/GoT/characters.json"
with open(character_info_file) as in_file:
    character_info = json.load(in_file)
    character_info = character_info["characters"]

# %%
character_info[0:2]
# Out:
# [{'characterName': 'Addam Marbrand',
#   'characterLink': '/character/ch0305333/',
#   'actorName': 'B.J. Hogg',
#   'actorLink': '/name/nm0389698/'},
#  {'characterName': 'Aegon Targaryen',
#   'houseName': 'Targaryen',
#   'royal': True,
#   'parents': ['Elia Martell', 'Rhaegar Targaryen'],
#   'siblings': ['Rhaenys Targaryen', 'Jon Snow'],
#   'killedBy': ['Gregor Clegane']}]

# %%
collection = database["characters"]
result = collection.insert_many(character_info)
result.inserted_ids
# Out:
# [ObjectId('67f0f82eeb5a9851a3008ec3'),
#  ObjectId('67f0f82eeb5a9851a3008ec4'),
#  ObjectId('67f0f82eeb5a9851a3008ec5'),
#  ObjectId('67f0f82eeb5a9851a3008ec6'),
#  ObjectId('67f0f82eeb5a9851a3008ec7'),
#  ObjectId('67f0f82eeb5a9851a3008ec8'),
#  ObjectId('67f0f82eeb5a9851a3008ec9'),
#  ObjectId('67f0f82eeb5a9851a3008eca'),
#  ObjectId('67f0f82eeb5a9851a3008ecb'),
#  ObjectId('67f0f82eeb5a9851a3008ecc'),
#  ObjectId('67f0f82eeb5a9851a3008ecd'),
#  ObjectId('67f0f82eeb5a9851a3008ece'),
#  ObjectId('67f0f82eeb5a9851a3008ecf'),
#  ObjectId('67f0f82eeb5a9851a3008ed0'),
#  ObjectId('67f0f82eeb5a9851a3008ed1'),
#  ObjectId('67f0f82eeb5a9851a3008ed2'),
#  ObjectId('67f0f82eeb5a9851a3008ed3'),
#  ObjectId('67f0f82eeb5a9851a3008ed4'),
#  ObjectId('67f0f82eeb5a9851a3008ed5'),
#  ObjectId('67f0f82eeb5a9851a3008ed6'),
#  ObjectId('67f0f82eeb5a9851a3008ed7'),
#  ObjectId('67f0f82eeb5a9851a3008ed8'),
#  ObjectId('67f0f82eeb5a9851a3008ed9'),
#  ObjectId('67f0f82eeb5a9851a3008eda'),
#  ObjectId('67f0f82eeb5a9851a3008edb'),
#  ObjectId('67f0f82eeb5a9851a3008edc'),
#  ObjectId('67f0f82eeb5a9851a3008edd'),
#  ObjectId('67f0f82eeb5a9851a3008ede'),
#  ObjectId('67f0f82eeb5a9851a3008edf'),
#  ObjectId('67f0f82eeb5a9851a3008ee0'),
#  ObjectId('67f0f82eeb5a9851a3008ee1'),
#  ObjectId('67f0f82eeb5a9851a3008ee2'),
#  ObjectId('67f0f82eeb5a9851a3008ee3'),
#  ObjectId('67f0f82eeb5a9851a3008ee4'),
#  ObjectId('67f0f82eeb5a9851a3008ee5'),
#  ObjectId('67f0f82eeb5a9851a3008ee6'),
#  ObjectId('67f0f82eeb5a9851a3008ee7'),
#  ObjectId('67f0f82eeb5a9851a3008ee8'),
#  ObjectId('67f0f82eeb5a9851a3008ee9'),
#  ObjectId('67f0f82eeb5a9851a3008eea'),
#  ObjectId('67f0f82eeb5a9851a3008eeb'),
#  ObjectId('67f0f82eeb5a9851a3008eec'),
#  ObjectId('67f0f82eeb5a9851a3008eed'),
#  ObjectId('67f0f82eeb5a9851a3008eee'),
#  ObjectId('67f0f82eeb5a9851a3008eef'),
#  ObjectId('67f0f82eeb5a9851a3008ef0'),
#  ObjectId('67f0f82eeb5a9851a3008ef1'),
#  ObjectId('67f0f82eeb5a9851a3008ef2'),
#  ObjectId('67f0f82eeb5a9851a3008ef3'),
#  ObjectId('67f0f82eeb5a9851a3008ef4'),
#  ObjectId('67f0f82eeb5a9851a3008ef5'),
#  ObjectId('67f0f82eeb5a9851a3008ef6'),
#  ObjectId('67f0f82eeb5a9851a3008ef7'),
#  ObjectId('67f0f82eeb5a9851a3008ef8'),
#  ObjectId('67f0f82eeb5a9851a3008ef9'),
#  ObjectId('67f0f82eeb5a9851a3008efa'),
#  ObjectId('67f0f82eeb5a9851a3008efb'),
#  ObjectId('67f0f82eeb5a9851a3008efc'),
#  ObjectId('67f0f82eeb5a9851a3008efd'),
#  ObjectId('67f0f82eeb5a9851a3008efe'),
#  ObjectId('67f0f82eeb5a9851a3008eff'),
#  ObjectId('67f0f82eeb5a9851a3008f00'),
#  ObjectId('67f0f82eeb5a9851a3008f01'),
#  ObjectId('67f0f82eeb5a9851a3008f02'),
#  ObjectId('67f0f82eeb5a9851a3008f03'),
#  ObjectId('67f0f82eeb5a9851a3008f04'),
#  ObjectId('67f0f82eeb5a9851a3008f05'),
#  ObjectId('67f0f82eeb5a9851a3008f06'),
#  ObjectId('67f0f82eeb5a9851a3008f07'),
#  ObjectId('67f0f82eeb5a9851a3008f08'),
#  ObjectId('67f0f82eeb5a9851a3008f09'),
#  ObjectId('67f0f82eeb5a9851a3008f0a'),
#  ObjectId('67f0f82eeb5a9851a3008f0b'),
#  ObjectId('67f0f82eeb5a9851a3008f0c'),
#  ObjectId('67f0f82eeb5a9851a3008f0d'),
#  ObjectId('67f0f82eeb5a9851a3008f0e'),
#  ObjectId('67f0f82eeb5a9851a3008f0f'),
#  ObjectId('67f0f82eeb5a9851a3008f10'),
#  ObjectId('67f0f82eeb5a9851a3008f11'),
#  ObjectId('67f0f82eeb5a9851a3008f12'),
#  ObjectId('67f0f82eeb5a9851a3008f13'),
#  ObjectId('67f0f82eeb5a9851a3008f14'),
#  ObjectId('67f0f82eeb5a9851a3008f15'),
#  ObjectId('67f0f82eeb5a9851a3008f16'),
#  ObjectId('67f0f82eeb5a9851a3008f17'),
#  ObjectId('67f0f82eeb5a9851a3008f18'),
#  ObjectId('67f0f82eeb5a9851a3008f19'),
#  ObjectId('67f0f82eeb5a9851a3008f1a'),
#  ObjectId('67f0f82eeb5a9851a3008f1b'),
#  ObjectId('67f0f82eeb5a9851a3008f1c'),
#  ObjectId('67f0f82eeb5a9851a3008f1d'),
#  ObjectId('67f0f82eeb5a9851a3008f1e'),
#  ObjectId('67f0f82eeb5a9851a3008f1f'),
#  ObjectId('67f0f82eeb5a9851a3008f20'),
#  ObjectId('67f0f82eeb5a9851a3008f21'),
#  ObjectId('67f0f82eeb5a9851a3008f22'),
#  ObjectId('67f0f82eeb5a9851a3008f23'),
#  ObjectId('67f0f82eeb5a9851a3008f24'),
#  ObjectId('67f0f82eeb5a9851a3008f25'),
#  ObjectId('67f0f82eeb5a9851a3008f26'),
#  ObjectId('67f0f82eeb5a9851a3008f27'),
#  ObjectId('67f0f82eeb5a9851a3008f28'),
#  ObjectId('67f0f82eeb5a9851a3008f29'),
#  ObjectId('67f0f82eeb5a9851a3008f2a'),
#  ObjectId('67f0f82eeb5a9851a3008f2b'),
#  ObjectId('67f0f82eeb5a9851a3008f2c'),
#  ObjectId('67f0f82eeb5a9851a3008f2d'),
#  ObjectId('67f0f82eeb5a9851a3008f2e'),
#  ObjectId('67f0f82eeb5a9851a3008f2f'),
#  ObjectId('67f0f82eeb5a9851a3008f30'),
#  ObjectId('67f0f82eeb5a9851a3008f31'),
#  ObjectId('67f0f82eeb5a9851a3008f32'),
#  ObjectId('67f0f82eeb5a9851a3008f33'),
#  ObjectId('67f0f82eeb5a9851a3008f34'),
#  ObjectId('67f0f82eeb5a9851a3008f35'),
#  ObjectId('67f0f82eeb5a9851a3008f36'),
#  ObjectId('67f0f82eeb5a9851a3008f37'),
#  ObjectId('67f0f82eeb5a9851a3008f38'),
#  ObjectId('67f0f82eeb5a9851a3008f39'),
#  ObjectId('67f0f82eeb5a9851a3008f3a'),
#  ObjectId('67f0f82eeb5a9851a3008f3b'),
#  ObjectId('67f0f82eeb5a9851a3008f3c'),
#  ObjectId('67f0f82eeb5a9851a3008f3d'),
#  ObjectId('67f0f82eeb5a9851a3008f3e'),
#  ObjectId('67f0f82eeb5a9851a3008f3f'),
#  ObjectId('67f0f82eeb5a9851a3008f40'),
#  ObjectId('67f0f82eeb5a9851a3008f41'),
#  ObjectId('67f0f82eeb5a9851a3008f42'),
#  ObjectId('67f0f82eeb5a9851a3008f43'),
#  ObjectId('67f0f82eeb5a9851a3008f44'),
#  ObjectId('67f0f82eeb5a9851a3008f45'),
#  ObjectId('67f0f82eeb5a9851a3008f46'),
#  ObjectId('67f0f82eeb5a9851a3008f47'),
#  ObjectId('67f0f82eeb5a9851a3008f48'),
#  ObjectId('67f0f82eeb5a9851a3008f49'),
#  ObjectId('67f0f82eeb5a9851a3008f4a'),
#  ObjectId('67f0f82eeb5a9851a3008f4b'),
#  ObjectId('67f0f82eeb5a9851a3008f4c'),
#  ObjectId('67f0f82eeb5a9851a3008f4d'),
#  ObjectId('67f0f82eeb5a9851a3008f4e'),
#  ObjectId('67f0f82eeb5a9851a3008f4f'),
#  ObjectId('67f0f82eeb5a9851a3008f50'),
#  ObjectId('67f0f82eeb5a9851a3008f51'),
#  ObjectId('67f0f82eeb5a9851a3008f52'),
#  ObjectId('67f0f82eeb5a9851a3008f53'),
#  ObjectId('67f0f82eeb5a9851a3008f54'),
#  ObjectId('67f0f82eeb5a9851a3008f55'),
#  ObjectId('67f0f82eeb5a9851a3008f56'),
#  ObjectId('67f0f82eeb5a9851a3008f57'),
#  ObjectId('67f0f82eeb5a9851a3008f58'),
#  ObjectId('67f0f82eeb5a9851a3008f59'),
#  ObjectId('67f0f82eeb5a9851a3008f5a'),
#  ObjectId('67f0f82eeb5a9851a3008f5b'),
#  ObjectId('67f0f82eeb5a9851a3008f5c'),
#  ObjectId('67f0f82eeb5a9851a3008f5d'),
#  ObjectId('67f0f82eeb5a9851a3008f5e'),
#  ObjectId('67f0f82eeb5a9851a3008f5f'),
#  ObjectId('67f0f82eeb5a9851a3008f60'),
#  ObjectId('67f0f82eeb5a9851a3008f61'),
#  ObjectId('67f0f82eeb5a9851a3008f62'),
#  ObjectId('67f0f82eeb5a9851a3008f63'),
#  ObjectId('67f0f82eeb5a9851a3008f64'),
#  ObjectId('67f0f82eeb5a9851a3008f65'),
#  ObjectId('67f0f82eeb5a9851a3008f66'),
#  ObjectId('67f0f82eeb5a9851a3008f67'),
#  ObjectId('67f0f82eeb5a9851a3008f68'),
#  ObjectId('67f0f82eeb5a9851a3008f69'),
#  ObjectId('67f0f82eeb5a9851a3008f6a'),
#  ObjectId('67f0f82eeb5a9851a3008f6b'),
#  ObjectId('67f0f82eeb5a9851a3008f6c'),
#  ObjectId('67f0f82eeb5a9851a3008f6d'),
#  ObjectId('67f0f82eeb5a9851a3008f6e'),
#  ObjectId('67f0f82eeb5a9851a3008f6f'),
#  ObjectId('67f0f82eeb5a9851a3008f70'),
#  ObjectId('67f0f82eeb5a9851a3008f71'),
#  ObjectId('67f0f82eeb5a9851a3008f72'),
#  ObjectId('67f0f82eeb5a9851a3008f73'),
#  ObjectId('67f0f82eeb5a9851a3008f74'),
#  ObjectId('67f0f82eeb5a9851a3008f75'),
#  ObjectId('67f0f82eeb5a9851a3008f76'),
#  ObjectId('67f0f82eeb5a9851a3008f77'),
#  ObjectId('67f0f82eeb5a9851a3008f78'),
#  ObjectId('67f0f82eeb5a9851a3008f79'),
#  ObjectId('67f0f82eeb5a9851a3008f7a'),
#  ObjectId('67f0f82eeb5a9851a3008f7b'),
#  ObjectId('67f0f82eeb5a9851a3008f7c'),
#  ObjectId('67f0f82eeb5a9851a3008f7d'),
#  ObjectId('67f0f82eeb5a9851a3008f7e'),
#  ObjectId('67f0f82eeb5a9851a3008f7f'),
#  ObjectId('67f0f82eeb5a9851a3008f80'),
#  ObjectId('67f0f82eeb5a9851a3008f81'),
#  ObjectId('67f0f82eeb5a9851a3008f82'),
#  ObjectId('67f0f82eeb5a9851a3008f83'),
#  ObjectId('67f0f82eeb5a9851a3008f84'),
#  ObjectId('67f0f82eeb5a9851a3008f85'),
#  ObjectId('67f0f82eeb5a9851a3008f86'),
#  ObjectId('67f0f82eeb5a9851a3008f87'),
#  ObjectId('67f0f82eeb5a9851a3008f88'),
#  ObjectId('67f0f82eeb5a9851a3008f89'),
#  ObjectId('67f0f82eeb5a9851a3008f8a'),
#  ObjectId('67f0f82eeb5a9851a3008f8b'),
#  ObjectId('67f0f82eeb5a9851a3008f8c'),
#  ObjectId('67f0f82eeb5a9851a3008f8d'),
#  ObjectId('67f0f82eeb5a9851a3008f8e'),
#  ObjectId('67f0f82eeb5a9851a3008f8f'),
#  ObjectId('67f0f82eeb5a9851a3008f90'),
#  ObjectId('67f0f82eeb5a9851a3008f91'),
#  ObjectId('67f0f82eeb5a9851a3008f92'),
#  ObjectId('67f0f82eeb5a9851a3008f93'),
#  ObjectId('67f0f82eeb5a9851a3008f94'),
#  ObjectId('67f0f82eeb5a9851a3008f95'),
#  ObjectId('67f0f82eeb5a9851a3008f96'),
#  ObjectId('67f0f82eeb5a9851a3008f97'),
#  ObjectId('67f0f82eeb5a9851a3008f98'),
#  ObjectId('67f0f82eeb5a9851a3008f99'),
#  ObjectId('67f0f82eeb5a9851a3008f9a'),
#  ObjectId('67f0f82eeb5a9851a3008f9b'),
#  ObjectId('67f0f82eeb5a9851a3008f9c'),
#  ObjectId('67f0f82eeb5a9851a3008f9d'),
#  ObjectId('67f0f82eeb5a9851a3008f9e'),
#  ObjectId('67f0f82eeb5a9851a3008f9f'),
#  ObjectId('67f0f82eeb5a9851a3008fa0'),
#  ObjectId('67f0f82eeb5a9851a3008fa1'),
#  ObjectId('67f0f82eeb5a9851a3008fa2'),
#  ObjectId('67f0f82eeb5a9851a3008fa3'),
#  ObjectId('67f0f82eeb5a9851a3008fa4'),
#  ObjectId('67f0f82eeb5a9851a3008fa5'),
#  ObjectId('67f0f82eeb5a9851a3008fa6'),
#  ObjectId('67f0f82eeb5a9851a3008fa7'),
#  ObjectId('67f0f82eeb5a9851a3008fa8'),
#  ObjectId('67f0f82eeb5a9851a3008fa9'),
#  ObjectId('67f0f82eeb5a9851a3008faa'),
#  ObjectId('67f0f82eeb5a9851a3008fab'),
#  ObjectId('67f0f82eeb5a9851a3008fac'),
#  ObjectId('67f0f82eeb5a9851a3008fad'),
#  ObjectId('67f0f82eeb5a9851a3008fae'),
#  ObjectId('67f0f82eeb5a9851a3008faf'),
#  ObjectId('67f0f82eeb5a9851a3008fb0'),
#  ObjectId('67f0f82eeb5a9851a3008fb1'),
#  ObjectId('67f0f82eeb5a9851a3008fb2'),
#  ObjectId('67f0f82eeb5a9851a3008fb3'),
#  ObjectId('67f0f82eeb5a9851a3008fb4'),
#  ObjectId('67f0f82eeb5a9851a3008fb5'),
#  ObjectId('67f0f82eeb5a9851a3008fb6'),
#  ObjectId('67f0f82eeb5a9851a3008fb7'),
#  ObjectId('67f0f82eeb5a9851a3008fb8'),
#  ObjectId('67f0f82eeb5a9851a3008fb9'),
#  ObjectId('67f0f82eeb5a9851a3008fba'),
#  ObjectId('67f0f82eeb5a9851a3008fbb'),
#  ObjectId('67f0f82eeb5a9851a3008fbc'),
#  ObjectId('67f0f82eeb5a9851a3008fbd'),
#  ObjectId('67f0f82eeb5a9851a3008fbe'),
#  ObjectId('67f0f82eeb5a9851a3008fbf'),
#  ObjectId('67f0f82eeb5a9851a3008fc0'),
#  ObjectId('67f0f82eeb5a9851a3008fc1'),
#  ObjectId('67f0f82eeb5a9851a3008fc2'),
#  ObjectId('67f0f82eeb5a9851a3008fc3'),
#  ObjectId('67f0f82eeb5a9851a3008fc4'),
#  ObjectId('67f0f82eeb5a9851a3008fc5'),
#  ObjectId('67f0f82eeb5a9851a3008fc6'),
#  ObjectId('67f0f82eeb5a9851a3008fc7'),
#  ObjectId('67f0f82eeb5a9851a3008fc8'),
#  ObjectId('67f0f82eeb5a9851a3008fc9'),
#  ObjectId('67f0f82eeb5a9851a3008fca'),
#  ObjectId('67f0f82eeb5a9851a3008fcb'),
#  ObjectId('67f0f82eeb5a9851a3008fcc'),
#  ObjectId('67f0f82eeb5a9851a3008fcd'),
#  ObjectId('67f0f82eeb5a9851a3008fce'),
#  ObjectId('67f0f82eeb5a9851a3008fcf'),
#  ObjectId('67f0f82eeb5a9851a3008fd0'),
#  ObjectId('67f0f82eeb5a9851a3008fd1'),
#  ObjectId('67f0f82eeb5a9851a3008fd2'),
#  ObjectId('67f0f82eeb5a9851a3008fd3'),
#  ObjectId('67f0f82eeb5a9851a3008fd4'),
#  ObjectId('67f0f82eeb5a9851a3008fd5'),
#  ObjectId('67f0f82eeb5a9851a3008fd6'),
#  ObjectId('67f0f82eeb5a9851a3008fd7'),
#  ObjectId('67f0f82eeb5a9851a3008fd8'),
#  ObjectId('67f0f82eeb5a9851a3008fd9'),
#  ObjectId('67f0f82eeb5a9851a3008fda'),
#  ObjectId('67f0f82eeb5a9851a3008fdb'),
#  ObjectId('67f0f82eeb5a9851a3008fdc'),
#  ObjectId('67f0f82eeb5a9851a3008fdd'),
#  ObjectId('67f0f82eeb5a9851a3008fde'),
#  ObjectId('67f0f82eeb5a9851a3008fdf'),
#  ObjectId('67f0f82eeb5a9851a3008fe0'),
#  ObjectId('67f0f82eeb5a9851a3008fe1'),
#  ObjectId('67f0f82eeb5a9851a3008fe2'),
#  ObjectId('67f0f82eeb5a9851a3008fe3'),
#  ObjectId('67f0f82eeb5a9851a3008fe4'),
#  ObjectId('67f0f82eeb5a9851a3008fe5'),
#  ObjectId('67f0f82eeb5a9851a3008fe6'),
#  ObjectId('67f0f82eeb5a9851a3008fe7'),
#  ObjectId('67f0f82eeb5a9851a3008fe8'),
#  ObjectId('67f0f82eeb5a9851a3008fe9'),
#  ObjectId('67f0f82eeb5a9851a3008fea'),
#  ObjectId('67f0f82eeb5a9851a3008feb'),
#  ObjectId('67f0f82eeb5a9851a3008fec'),
#  ObjectId('67f0f82eeb5a9851a3008fed'),
#  ObjectId('67f0f82eeb5a9851a3008fee'),
#  ObjectId('67f0f82eeb5a9851a3008fef'),
#  ObjectId('67f0f82eeb5a9851a3008ff0'),
#  ObjectId('67f0f82eeb5a9851a3008ff1'),
#  ObjectId('67f0f82eeb5a9851a3008ff2'),
#  ObjectId('67f0f82eeb5a9851a3008ff3'),
#  ObjectId('67f0f82eeb5a9851a3008ff4'),
#  ObjectId('67f0f82eeb5a9851a3008ff5'),
#  ObjectId('67f0f82eeb5a9851a3008ff6'),
#  ObjectId('67f0f82eeb5a9851a3008ff7'),
#  ObjectId('67f0f82eeb5a9851a3008ff8'),
#  ObjectId('67f0f82eeb5a9851a3008ff9'),
#  ObjectId('67f0f82eeb5a9851a3008ffa'),
#  ObjectId('67f0f82eeb5a9851a3008ffb'),
#  ObjectId('67f0f82eeb5a9851a3008ffc'),
#  ObjectId('67f0f82eeb5a9851a3008ffd'),
#  ObjectId('67f0f82eeb5a9851a3008ffe'),
#  ObjectId('67f0f82eeb5a9851a3008fff'),
#  ObjectId('67f0f82eeb5a9851a3009000'),
#  ObjectId('67f0f82eeb5a9851a3009001'),
#  ObjectId('67f0f82eeb5a9851a3009002'),
#  ObjectId('67f0f82eeb5a9851a3009003'),
#  ObjectId('67f0f82eeb5a9851a3009004'),
#  ObjectId('67f0f82eeb5a9851a3009005'),
#  ObjectId('67f0f82eeb5a9851a3009006'),
#  ObjectId('67f0f82eeb5a9851a3009007'),
#  ObjectId('67f0f82eeb5a9851a3009008'),
#  ObjectId('67f0f82eeb5a9851a3009009'),
#  ObjectId('67f0f82eeb5a9851a300900a'),
#  ObjectId('67f0f82eeb5a9851a300900b'),
#  ObjectId('67f0f82eeb5a9851a300900c'),
#  ObjectId('67f0f82eeb5a9851a300900d'),
#  ObjectId('67f0f82eeb5a9851a300900e'),
#  ObjectId('67f0f82eeb5a9851a300900f'),
#  ObjectId('67f0f82eeb5a9851a3009010'),
#  ObjectId('67f0f82eeb5a9851a3009011'),
#  ObjectId('67f0f82eeb5a9851a3009012'),
#  ObjectId('67f0f82eeb5a9851a3009013'),
#  ObjectId('67f0f82eeb5a9851a3009014'),
#  ObjectId('67f0f82eeb5a9851a3009015'),
#  ObjectId('67f0f82eeb5a9851a3009016'),
#  ObjectId('67f0f82eeb5a9851a3009017'),
#  ObjectId('67f0f82eeb5a9851a3009018'),
#  ObjectId('67f0f82eeb5a9851a3009019'),
#  ObjectId('67f0f82eeb5a9851a300901a'),
#  ObjectId('67f0f82eeb5a9851a300901b'),
#  ObjectId('67f0f82eeb5a9851a300901c'),
#  ObjectId('67f0f82eeb5a9851a300901d'),
#  ObjectId('67f0f82eeb5a9851a300901e'),
#  ObjectId('67f0f82eeb5a9851a300901f'),
#  ObjectId('67f0f82eeb5a9851a3009020'),
#  ObjectId('67f0f82eeb5a9851a3009021'),
#  ObjectId('67f0f82eeb5a9851a3009022'),
#  ObjectId('67f0f82eeb5a9851a3009023'),
#  ObjectId('67f0f82eeb5a9851a3009024'),
#  ObjectId('67f0f82eeb5a9851a3009025'),
#  ObjectId('67f0f82eeb5a9851a3009026'),
#  ObjectId('67f0f82eeb5a9851a3009027'),
#  ObjectId('67f0f82eeb5a9851a3009028'),
#  ObjectId('67f0f82eeb5a9851a3009029'),
#  ObjectId('67f0f82eeb5a9851a300902a'),
#  ObjectId('67f0f82eeb5a9851a300902b'),
#  ObjectId('67f0f82eeb5a9851a300902c'),
#  ObjectId('67f0f82eeb5a9851a300902d'),
#  ObjectId('67f0f82eeb5a9851a300902e'),
#  ObjectId('67f0f82eeb5a9851a300902f'),
#  ObjectId('67f0f82eeb5a9851a3009030'),
#  ObjectId('67f0f82eeb5a9851a3009031'),
#  ObjectId('67f0f82eeb5a9851a3009032'),
#  ObjectId('67f0f82eeb5a9851a3009033'),
#  ObjectId('67f0f82eeb5a9851a3009034'),
#  ObjectId('67f0f82eeb5a9851a3009035'),
#  ObjectId('67f0f82eeb5a9851a3009036'),
#  ObjectId('67f0f82eeb5a9851a3009037'),
#  ObjectId('67f0f82eeb5a9851a3009038'),
#  ObjectId('67f0f82eeb5a9851a3009039'),
#  ObjectId('67f0f82eeb5a9851a300903a'),
#  ObjectId('67f0f82eeb5a9851a300903b'),
#  ObjectId('67f0f82eeb5a9851a300903c'),
#  ObjectId('67f0f82eeb5a9851a300903d'),
#  ObjectId('67f0f82eeb5a9851a300903e'),
#  ObjectId('67f0f82eeb5a9851a300903f'),
#  ObjectId('67f0f82eeb5a9851a3009040'),
#  ObjectId('67f0f82eeb5a9851a3009041'),
#  ObjectId('67f0f82eeb5a9851a3009042'),
#  ObjectId('67f0f82eeb5a9851a3009043'),
#  ObjectId('67f0f82eeb5a9851a3009044'),
#  ObjectId('67f0f82eeb5a9851a3009045'),
#  ObjectId('67f0f82eeb5a9851a3009046'),
#  ObjectId('67f0f82eeb5a9851a3009047')]

# %% [markdown]
# You are golden for now.

# %% [markdown]
# ## Load the Character Information into Aura

# %%
# Rerunning the slightly modified code from above.
#
class Neo4jAuraDB:
    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))
        # print("Created driver.")

    def close(self):
        self.driver.close()

    def create_character_node(self, label, properties):
        with self.driver.session() as session:
            session.execute_write(self._create_node, label, properties)

    def count_characters(self):
        with self.driver.session() as session:
            query = "match (n:GoT:Character) return count(n)"
            records, summary, keys = driver.execute_query(
                query
            )
            # Loop through results and do something with them
            for record in records:
                print(record.data())
        

    def _create_node(self, tx, label, properties):
        
        # Build Cypher property string: key1: $key1, key2: $key2, ...
        prop_string = ", ".join([f"{k}: ${k}" for k in properties.keys()])
        
        # Final Cypher query
        query = f"CREATE (c:{label} {{ {prop_string} }})"

        # print(query)
        
        tx.run(query, **properties)
    
    def insert_character(self, c):
        # Some of the fields that interest use might be None.
        # So, we just get the fields we want.
        #
        fields = ["characterName", "characterLink", "actorName", "actorLink", "houseName",
                "royal", "kingsguard"
                ]
        new_c = dict()
        for f in fields:
           v = c.get(f, None)
           if v:
               new_c[f] = v
        self.create_character_node("GoT:Character", new_c)
        # print("This seems to have worked.")

# %%
# Now let's insert the characters.
#
db = Neo4jAuraDB(NEO4J_URI, NEO4J_USERNAME, NEO4J_PASSWORD)
try:
    for c in character_info:
        people = db.insert_character(character_info[0])
finally:
    # db.close()
    pass

# %%
# %ls $imdb_data_dir

# %%
# How many were created?
db = Neo4jAuraDB(NEO4J_URI, NEO4J_USERNAME, NEO4J_PASSWORD)
db.count_characters()
# Out:
# /var/folders/z3/vlph6tsj7tj_46413t0z42tc0000gp/T/ipykernel_81178/2917380557.py:18: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   records, summary, keys = driver.execute_query(
# {'count(n)': 389}

# %%
# %sql drop database if exists s25_project

# %%
# %sql create database s25_project

# %% [markdown]
# We are simply going to load the data for now. The data files do not have a header row identifying the
# columns. So, we have to define the columns and not use the header inferring for the file read.

# %%
name_basics_df = pandas.read_csv(imdb_data_dir + '/got_imdb_name_basics.csv', 
                                  header=None)

# %%
name_basics_df.columns = ["nconst", "primaryName", "birthYear", "deathYear", 
                          "primaryProfession", "knownForTitles"]

# %%
name_basics_df.to_sql('name_basics', schema='s25_project',
                      con=default_engine, index=False, if_exists='append')

# %%
# %sql use s25_project

# %%
# %sql select * from name_basics limit 5;

# %%
title_basics_df = pandas.read_csv(imdb_data_dir + '/got_imdb_title_basics.csv', header=None)

# %%
title_basics_df.columns = ["tconst", "titleType", "primaryTitle",
                          "originalTitle", "isAdult", "startYear", "endYear",
                          "runtimeMinutes", "genres"]

# %%
title_basics_df.to_sql('title_basics', schema='s25_project',
                      con=default_engine, index=False, if_exists='replace')

# %%
title_principals_df = pandas.read_csv(imdb_data_dir + '/got_imdb_title_principals.csv', header=None)

# %%
title_principals_df.head(5)

# %%
title_principals_df.columns = ["nconst", "tconst", "ordering", "category", "job", "characters"]

# %%
title_principals_df.to_sql('title_principals', schema='s25_project',
                      con=default_engine, index=False, if_exists='replace')

# %%
# %sql select * from title_principals limit 5;

# %%
title_ratings_df = pandas.read_csv(imdb_data_dir + '/got_imdb_title_ratings.csv')

# %%
title_ratings_df.columns= ['tconst', "averageRating", "noOfVotes"]

# %%
title_ratings_df.to_sql('title_ratings', schema='s25_project',
                      con=default_engine, index=False, if_exists='replace')

# %%
# %sql select * from title_ratings limit 5;
